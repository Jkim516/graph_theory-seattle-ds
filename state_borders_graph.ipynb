# %% [markdown]
# # Graphing the US State Borders

# %%
import pandas as pd
import networkx as nx

# %%
state_borders = {'AL': {'FL': {'weight': 0.01}, 'GA': {'weight': 0.01},
                        'MS': {'weight': 0.01}, 'TN': {'weight': 0.01}},
                'AK': {},
                'AZ': {'CA': {'weight': 0.01}, 'NV': {'weight': 0.01},
                       'NM': {'weight': 0.01}, 'UT': {'weight': 0.01}},
                'AR': {'LA': {'weight': 0.01}, 'MS': {'weight': 0.01},
                       'MO': {'weight': 0.01}, 'OK': {'weight': 0.01},
                       'TN': {'weight': 0.01}, 'TX': {'weight': 0.01}},
                'CA': {'AZ': {'weight': 0.01}, 'NV': {'weight': 0.01},
                       'OR': {'weight': 0.01}},
                'CO': {'KS': {'weight': 0.01}, 'NE': {'weight': 0.01},
                       'NM': {'weight': 0.01}, 'OK': {'weight': 0.01},
                       'UT': {'weight': 0.01}, 'WY': {'weight': 0.01}},
                'CT': {'MA': {'weight': 0.1}, 'NY': {'weight': 0.1},
                       'RI': {'weight': 0.1}},
                'DE': {'MD': {'weight': 0.1}, 'NJ': {'weight': 0.1},
                       'PA': {'weight': 0.1}},
                'FL': {'AL': {'weight': 0.01}, 'GA': {'weight': 0.01}},
                'GA': {'AL': {'weight': 0.01}, 'FL': {'weight': 0.01},
                       'NC': {'weight': 0.01}, 'SC': {'weight': 0.01},
                       'TN': {'weight': 0.01}},
                'HI': {},
                'ID': {'MT': {'weight': 0.01}, 'NV': {'weight': 0.01},
                       'OR': {'weight': 0.01}, 'UT': {'weight': 0.01},
                       'WA': {'weight': 0.01}, 'WY': {'weight': 0.01}},
                'IL': {'IN': {'weight': 0.01}, 'IA': {'weight': 0.01},
                       'KY': {'weight': 0.01}, 'MO': {'weight': 0.01},
                       'WI': {'weight': 0.01}},
                'IN': {'IL': {'weight': 0.01}, 'KY': {'weight': 0.01},
                       'MI': {'weight': 0.01}, 'OH': {'weight': 0.01}},
                'IA': {'IL': {'weight': 0.01}, 'MN': {'weight': 0.01},
                       'MO': {'weight': 0.01}, 'NE': {'weight': 0.01},
                       'SD': {'weight': 0.01}, 'WI': {'weight': 0.01}},
                'KS': {'CO': {'weight': 0.01}, 'MO': {'weight': 0.01},
                       'NE': {'weight': 0.01}, 'OK': {'weight': 0.01}},
                'KY': {'IL': {'weight': 0.01}, 'IN': {'weight': 0.01},
                       'MO': {'weight': 0.01}, 'OH': {'weight': 0.01},
                       'TN': {'weight': 0.01}, 'VA': {'weight': 0.01},
                       'WV': {'weight': 0.01}},
                'LA': {'AR': {'weight': 0.01}, 'MS': {'weight': 0.01},
                       'TX': {'weight': 0.01}},
                'ME': {'NH': {'weight': 0.1}},
                'MD': {'DE': {'weight': 0.1}, 'PA': {'weight': 0.01},
                       'VA': {'weight': 0.01}, 'WV': {'weight': 0.01}},
                'MA': {'CT': {'weight': 0.1}, 'NH': {'weight': 0.1},
                       'NY': {'weight': 0.1}, 'RI': {'weight': 0.1},
                       'VT': {'weight': 0.1}},
                'MI': {'IN': {'weight': 0.01}, 'OH': {'weight': 0.01},
                       'WI': {'weight': 0.01}},
                'MN': {'IA': {'weight': 0.01}, 'ND': {'weight': 0.01},
                       'SD': {'weight': 0.01}, 'WI': {'weight': 0.01}},
                'MS': {'AL': {'weight': 0.01}, 'AR': {'weight': 0.01},
                       'LA': {'weight': 0.01}, 'TN': {'weight': 0.01}},
                'MO': {'AR': {'weight': 0.01}, 'IL': {'weight': 0.01},
                       'IA': {'weight': 0.01}, 'KS': {'weight': 0.01},
                       'KY': {'weight': 0.01}, 'NE': {'weight': 0.01},
                       'OK': {'weight': 0.01}, 'TN': {'weight': 0.01}},
                'MT': {'ID': {'weight': 0.01}, 'ND': {'weight': 0.01},
                       'SD': {'weight': 0.01}, 'WY': {'weight': 0.01}},
                'NE': {'CO': {'weight': 0.01}, 'IA': {'weight': 0.01},
                       'KS': {'weight': 0.01}, 'MO': {'weight': 0.01},
                       'SD': {'weight': 0.01}, 'WY': {'weight': 0.01}},
                'NV': {'AZ': {'weight': 0.01}, 'CA': {'weight': 0.01},
                       'ID': {'weight': 0.01}, 'OR': {'weight': 0.01},
                       'UT': {'weight': 0.01}},
                'NH': {'ME': {'weight': 0.1}, 'MA': {'weight': 0.1},
                       'VT': {'weight': 0.1}},
                'NJ': {'DE': {'weight': 0.1}, 'NY': {'weight': 0.1},
                       'PA': {'weight': 0.1}},
                'NM': {'AZ': {'weight': 0.01}, 'CO': {'weight': 0.01},
                       'OK': {'weight': 0.01}, 'TX': {'weight': 0.01}},
                'NY': {'CT': {'weight': 0.1}, 'MA': {'weight': 0.1},
                       'NJ': {'weight': 0.1}, 'PA': {'weight': 0.01},
                       'VT': {'weight': 0.1}},
                'NC': {'GA': {'weight': 0.01}, 'SC': {'weight': 0.01},
                       'TN': {'weight': 0.01}, 'VA': {'weight': 0.01}},
                'ND': {'MN': {'weight': 0.01}, 'MT': {'weight': 0.01},
                       'SD': {'weight': 0.01}},
                'OH': {'IN': {'weight': 0.01}, 'KY': {'weight': 0.01},
                       'MI': {'weight': 0.01}, 'PA': {'weight': 0.01},
                       'WV': {'weight': 0.01}},
                'OK': {'AR': {'weight': 0.01}, 'CO': {'weight': 0.01},
                       'KS': {'weight': 0.01}, 'MO': {'weight': 0.01},
                       'NM': {'weight': 0.01}, 'TX': {'weight': 0.01}},
                'OR': {'CA': {'weight': 0.01}, 'ID': {'weight': 0.01},
                       'NV': {'weight': 0.01}, 'WA': {'weight': 0.01}},
                'PA': {'DE': {'weight': 0.1}, 'MD': {'weight': 0.01},
                       'NJ': {'weight': 0.01}, 'NY': {'weight': 0.01},
                       'OH': {'weight': 0.01}, 'WV': {'weight': 0.01}},
                'RI': {'CT': {'weight': 0.1}, 'MA': {'weight': 0.1}},
                'SC': {'GA': {'weight': 0.01}, 'NC': {'weight': 0.01}},
                'SD': {'IA': {'weight': 0.01}, 'MN': {'weight': 0.01},
                       'MT': {'weight': 0.01}, 'NE': {'weight': 0.01},
                       'ND': {'weight': 0.01}, 'WY': {'weight': 0.01}},
                'TN': {'AL': {'weight': 0.01}, 'AR': {'weight': 0.01},
                       'GA': {'weight': 0.01}, 'KY': {'weight': 0.01},
                       'MS': {'weight': 0.01}, 'MO': {'weight': 0.01},
                       'NC': {'weight': 0.01}, 'VA': {'weight': 0.01}},
                'TX': {'AR': {'weight': 0.01}, 'LA': {'weight': 0.01},
                       'NM': {'weight': 0.01}, 'OK': {'weight': 0.01}},
                'UT': {'AZ': {'weight': 0.01}, 'CO': {'weight': 0.01},
                       'ID': {'weight': 0.01}, 'NV': {'weight': 0.01},
                       'WY': {'weight': 0.01}},
                'VT': {'MA': {'weight': 0.1}, 'NH': {'weight': 0.1},
                       'NY': {'weight': 0.1}},
                'VA': {'KY': {'weight': 0.01}, 'MD': {'weight': 0.01},
                       'NC': {'weight': 0.01}, 'TN': {'weight': 0.01},
                       'WV': {'weight': 0.01}},
                'WA': {'ID': {'weight': 0.01}, 'OR': {'weight': 0.01}},
                'WV': {'KY': {'weight': 0.01}, 'MD': {'weight': 0.01},
                       'OH': {'weight': 0.01}, 'PA': {'weight': 0.01},
                       'VA': {'weight': 0.01}},
                'WI': {'IL': {'weight': 0.01}, 'IA': {'weight': 0.01},
                       'MI': {'weight': 0.01}, 'MN': {'weight': 0.01}},
                'WY': {'CO': {'weight': 0.01}, 'ID': {'weight': 0.01}, 
                       'MT': {'weight': 0.01}, 'NE': {'weight': 0.01},
                       'SD': {'weight': 0.01}, 'UT': {'weight': 0.01}}}

# %%
borders = nx.from_dict_of_dicts(state_borders)

# %%
nx.draw(borders, with_labels=True)
# Out:
# /anaconda3/envs/learn-env/lib/python3.7/site-packages/networkx/drawing/nx_pylab.py:611: MatplotlibDeprecationWarning: isinstance(..., numbers.Number)
#   if cb.is_numlike(alpha):

# %%
state_borders48 = {}
for state in state_borders:
    if state_borders[state] != {}:
        state_borders48[state] = state_borders[state]

# %%
borders48 = nx.from_dict_of_dicts(state_borders48)

# %%
nx.draw(borders48, with_labels=True)
# Out:
# /anaconda3/envs/learn-env/lib/python3.7/site-packages/networkx/drawing/nx_pylab.py:611: MatplotlibDeprecationWarning: isinstance(..., numbers.Number)
#   if cb.is_numlike(alpha):

# %%
list(nx.isolates(borders))
# Out:
# ['AK', 'HI']

# %%
list(nx.all_pairs_dijkstra_path(borders))
# Out:
# [('AL',
#   {'AL': ['AL'],
#    'FL': ['AL', 'FL'],
#    'GA': ['AL', 'GA'],
#    'MS': ['AL', 'MS'],
#    'TN': ['AL', 'TN'],
#    'NC': ['AL', 'GA', 'NC'],
#    'SC': ['AL', 'GA', 'SC'],
#    'AR': ['AL', 'MS', 'AR'],
#    'LA': ['AL', 'MS', 'LA'],
#    'KY': ['AL', 'TN', 'KY'],
#    'MO': ['AL', 'TN', 'MO'],
#    'VA': ['AL', 'TN', 'VA'],
#    'OK': ['AL', 'MS', 'AR', 'OK'],
#    'TX': ['AL', 'MS', 'AR', 'TX'],
#    'IL': ['AL', 'TN', 'KY', 'IL'],
#    'IN': ['AL', 'TN', 'KY', 'IN'],
#    'OH': ['AL', 'TN', 'KY', 'OH'],
#    'WV': ['AL', 'TN', 'KY', 'WV'],
#    'IA': ['AL', 'TN', 'MO', 'IA'],
#    'KS': ['AL', 'TN', 'MO', 'KS'],
#    'NE': ['AL', 'TN', 'MO', 'NE'],
#    'MD': ['AL', 'TN', 'VA', 'MD'],
#    'CO': ['AL', 'MS', 'AR', 'OK', 'CO'],
#    'NM': ['AL', 'MS', 'AR', 'OK', 'NM'],
#    'WI': ['AL', 'TN', 'KY', 'IL', 'WI'],
#    'MI': ['AL', 'TN', 'KY', 'IN', 'MI'],
#    'PA': ['AL', 'TN', 'KY', 'OH', 'PA'],
#    'MN': ['AL', 'TN', 'MO', 'IA', 'MN'],
#    'SD': ['AL', 'TN', 'MO', 'IA', 'SD'],
#    'WY': ['AL', 'TN', 'MO', 'NE', 'WY'],
#    'DE': ['AL', 'TN', 'VA', 'MD', 'DE'],
#    'UT': ['AL', 'MS', 'AR', 'OK', 'CO', 'UT'],
#    'AZ': ['AL', 'MS', 'AR', 'OK', 'NM', 'AZ'],
#    'NJ': ['AL', 'TN', 'KY', 'OH', 'PA', 'NJ'],
#    'NY': ['AL', 'TN', 'KY', 'OH', 'PA', 'NY'],
#    'ND': ['AL', 'TN', 'MO', 'IA', 'MN', 'ND'],
#    'MT': ['AL', 'TN', 'MO', 'IA', 'SD', 'MT'],
#    'ID': ['AL', 'TN', 'MO', 'NE', 'WY', 'ID'],
#    'NV': ['AL', 'MS', 'AR', 'OK', 'CO', 'UT', 'NV'],
#    'CA': ['AL', 'MS', 'AR', 'OK', 'NM', 'AZ', 'CA'],
#    'CT': ['AL', 'TN', 'KY', 'OH', 'PA', 'NY', 'CT'],
#    'MA': ['AL', 'TN', 'KY', 'OH', 'PA', 'NY', 'MA'],
#    'VT': ['AL', 'TN', 'KY', 'OH', 'PA', 'NY', 'VT'],
#    'OR': ['AL', 'TN', 'MO', 'NE', 'WY', 'ID', 'OR'],
#    'WA': ['AL', 'TN', 'MO', 'NE', 'WY', 'ID', 'WA'],
#    'RI': ['AL', 'TN', 'KY', 'OH', 'PA', 'NY', 'CT', 'RI'],
#    'NH': ['AL', 'TN', 'KY', 'OH', 'PA', 'NY', 'MA', 'NH'],
#    'ME': ['AL', 'TN', 'KY', 'OH', 'PA', 'NY', 'MA', 'NH', 'ME']}),
#  ('AK', {'AK': ['AK']}),
#  ('AZ',
#   {'AZ': ['AZ'],
#    'CA': ['AZ', 'CA'],
#    'NV': ['AZ', 'NV'],
#    'NM': ['AZ', 'NM'],
#    'UT': ['AZ', 'UT'],
#    'OR': ['AZ', 'CA', 'OR'],
#    'ID': ['AZ', 'NV', 'ID'],
#    'CO': ['AZ', 'NM', 'CO'],
#    'OK': ['AZ', 'NM', 'OK'],
#    'TX': ['AZ', 'NM', 'TX'],
#    'WY': ['AZ', 'UT', 'WY'],
#    'WA': ['AZ', 'CA', 'OR', 'WA'],
#    'MT': ['AZ', 'NV', 'ID', 'MT'],
#    'KS': ['AZ', 'NM', 'CO', 'KS'],
#    'NE': ['AZ', 'NM', 'CO', 'NE'],
#    'AR': ['AZ', 'NM', 'OK', 'AR'],
#    'MO': ['AZ', 'NM', 'OK', 'MO'],
#    'LA': ['AZ', 'NM', 'TX', 'LA'],
#    'SD': ['AZ', 'UT', 'WY', 'SD'],
#    'ND': ['AZ', 'NV', 'ID', 'MT', 'ND'],
#    'IA': ['AZ', 'NM', 'CO', 'NE', 'IA'],
#    'MS': ['AZ', 'NM', 'OK', 'AR', 'MS'],
#    'TN': ['AZ', 'NM', 'OK', 'AR', 'TN'],
#    'IL': ['AZ', 'NM', 'OK', 'MO', 'IL'],
#    'KY': ['AZ', 'NM', 'OK', 'MO', 'KY'],
#    'MN': ['AZ', 'UT', 'WY', 'SD', 'MN'],
#    'WI': ['AZ', 'NM', 'CO', 'NE', 'IA', 'WI'],
#    'AL': ['AZ', 'NM', 'OK', 'AR', 'MS', 'AL'],
#    'GA': ['AZ', 'NM', 'OK', 'AR', 'TN', 'GA'],
#    'NC': ['AZ', 'NM', 'OK', 'AR', 'TN', 'NC'],
#    'VA': ['AZ', 'NM', 'OK', 'AR', 'TN', 'VA'],
#    'IN': ['AZ', 'NM', 'OK', 'MO', 'IL', 'IN'],
#    'OH': ['AZ', 'NM', 'OK', 'MO', 'KY', 'OH'],
#    'WV': ['AZ', 'NM', 'OK', 'MO', 'KY', 'WV'],
#    'MI': ['AZ', 'NM', 'CO', 'NE', 'IA', 'WI', 'MI'],
#    'FL': ['AZ', 'NM', 'OK', 'AR', 'MS', 'AL', 'FL'],
#    'SC': ['AZ', 'NM', 'OK', 'AR', 'TN', 'GA', 'SC'],
#    'MD': ['AZ', 'NM', 'OK', 'AR', 'TN', 'VA', 'MD'],
#    'PA': ['AZ', 'NM', 'OK', 'MO', 'KY', 'OH', 'PA'],
#    'DE': ['AZ', 'NM', 'OK', 'AR', 'TN', 'VA', 'MD', 'DE'],
#    'NJ': ['AZ', 'NM', 'OK', 'MO', 'KY', 'OH', 'PA', 'NJ'],
#    'NY': ['AZ', 'NM', 'OK', 'MO', 'KY', 'OH', 'PA', 'NY'],
#    'CT': ['AZ', 'NM', 'OK', 'MO', 'KY', 'OH', 'PA', 'NY', 'CT'],
#    'MA': ['AZ', 'NM', 'OK', 'MO', 'KY', 'OH', 'PA', 'NY', 'MA'],
#    'VT': ['AZ', 'NM', 'OK', 'MO', 'KY', 'OH', 'PA', 'NY', 'VT'],
#    'RI': ['AZ', 'NM', 'OK', 'MO', 'KY', 'OH', 'PA', 'NY', 'CT', 'RI'],
#    'NH': ['AZ', 'NM', 'OK', 'MO', 'KY', 'OH', 'PA', 'NY', 'MA', 'NH'],
#    'ME': ['AZ', 'NM', 'OK', 'MO', 'KY', 'OH', 'PA', 'NY', 'MA', 'NH', 'ME']}),
#  ('AR',
#   {'AR': ['AR'],
#    'LA': ['AR', 'LA'],
#    'MS': ['AR', 'MS'],
#    'MO': ['AR', 'MO'],
#    'OK': ['AR', 'OK'],
#    'TN': ['AR', 'TN'],
#    'TX': ['AR', 'TX'],
#    'AL': ['AR', 'MS', 'AL'],
#    'IL': ['AR', 'MO', 'IL'],
#    'IA': ['AR', 'MO', 'IA'],
#    'KS': ['AR', 'MO', 'KS'],
#    'KY': ['AR', 'MO', 'KY'],
#    'NE': ['AR', 'MO', 'NE'],
#    'CO': ['AR', 'OK', 'CO'],
#    'NM': ['AR', 'OK', 'NM'],
#    'GA': ['AR', 'TN', 'GA'],
#    'NC': ['AR', 'TN', 'NC'],
#    'VA': ['AR', 'TN', 'VA'],
#    'FL': ['AR', 'MS', 'AL', 'FL'],
#    'IN': ['AR', 'MO', 'IL', 'IN'],
#    'WI': ['AR', 'MO', 'IL', 'WI'],
#    'MN': ['AR', 'MO', 'IA', 'MN'],
#    'SD': ['AR', 'MO', 'IA', 'SD'],
#    'OH': ['AR', 'MO', 'KY', 'OH'],
#    'WV': ['AR', 'MO', 'KY', 'WV'],
#    'WY': ['AR', 'MO', 'NE', 'WY'],
#    'UT': ['AR', 'OK', 'CO', 'UT'],
#    'AZ': ['AR', 'OK', 'NM', 'AZ'],
#    'SC': ['AR', 'TN', 'GA', 'SC'],
#    'MD': ['AR', 'TN', 'VA', 'MD'],
#    'MI': ['AR', 'MO', 'IL', 'IN', 'MI'],
#    'ND': ['AR', 'MO', 'IA', 'MN', 'ND'],
#    'MT': ['AR', 'MO', 'IA', 'SD', 'MT'],
#    'PA': ['AR', 'MO', 'KY', 'OH', 'PA'],
#    'ID': ['AR', 'MO', 'NE', 'WY', 'ID'],
#    'NV': ['AR', 'OK', 'CO', 'UT', 'NV'],
#    'CA': ['AR', 'OK', 'NM', 'AZ', 'CA'],
#    'DE': ['AR', 'TN', 'VA', 'MD', 'DE'],
#    'NJ': ['AR', 'MO', 'KY', 'OH', 'PA', 'NJ'],
#    'NY': ['AR', 'MO', 'KY', 'OH', 'PA', 'NY'],
#    'OR': ['AR', 'MO', 'NE', 'WY', 'ID', 'OR'],
#    'WA': ['AR', 'MO', 'NE', 'WY', 'ID', 'WA'],
#    'CT': ['AR', 'MO', 'KY', 'OH', 'PA', 'NY', 'CT'],
#    'MA': ['AR', 'MO', 'KY', 'OH', 'PA', 'NY', 'MA'],
#    'VT': ['AR', 'MO', 'KY', 'OH', 'PA', 'NY', 'VT'],
#    'RI': ['AR', 'MO', 'KY', 'OH', 'PA', 'NY', 'CT', 'RI'],
#    'NH': ['AR', 'MO', 'KY', 'OH', 'PA', 'NY', 'MA', 'NH'],
#    'ME': ['AR', 'MO', 'KY', 'OH', 'PA', 'NY', 'MA', 'NH', 'ME']}),
#  ('CA',
#   {'CA': ['CA'],
#    'AZ': ['CA', 'AZ'],
#    'NV': ['CA', 'NV'],
#    'OR': ['CA', 'OR'],
#    'NM': ['CA', 'AZ', 'NM'],
#    'UT': ['CA', 'AZ', 'UT'],
#    'ID': ['CA', 'NV', 'ID'],
#    'WA': ['CA', 'OR', 'WA'],
#    'CO': ['CA', 'AZ', 'NM', 'CO'],
#    'OK': ['CA', 'AZ', 'NM', 'OK'],
#    'TX': ['CA', 'AZ', 'NM', 'TX'],
#    'WY': ['CA', 'AZ', 'UT', 'WY'],
#    'MT': ['CA', 'NV', 'ID', 'MT'],
#    'KS': ['CA', 'AZ', 'NM', 'CO', 'KS'],
#    'NE': ['CA', 'AZ', 'NM', 'CO', 'NE'],
#    'AR': ['CA', 'AZ', 'NM', 'OK', 'AR'],
#    'MO': ['CA', 'AZ', 'NM', 'OK', 'MO'],
#    'LA': ['CA', 'AZ', 'NM', 'TX', 'LA'],
#    'SD': ['CA', 'AZ', 'UT', 'WY', 'SD'],
#    'ND': ['CA', 'NV', 'ID', 'MT', 'ND'],
#    'IA': ['CA', 'AZ', 'NM', 'CO', 'NE', 'IA'],
#    'MS': ['CA', 'AZ', 'NM', 'OK', 'AR', 'MS'],
#    'TN': ['CA', 'AZ', 'NM', 'OK', 'AR', 'TN'],
#    'IL': ['CA', 'AZ', 'NM', 'OK', 'MO', 'IL'],
#    'KY': ['CA', 'AZ', 'NM', 'OK', 'MO', 'KY'],
#    'MN': ['CA', 'AZ', 'UT', 'WY', 'SD', 'MN'],
#    'WI': ['CA', 'AZ', 'NM', 'CO', 'NE', 'IA', 'WI'],
#    'AL': ['CA', 'AZ', 'NM', 'OK', 'AR', 'MS', 'AL'],
#    'GA': ['CA', 'AZ', 'NM', 'OK', 'AR', 'TN', 'GA'],
#    'NC': ['CA', 'AZ', 'NM', 'OK', 'AR', 'TN', 'NC'],
#    'VA': ['CA', 'AZ', 'NM', 'OK', 'AR', 'TN', 'VA'],
#    'IN': ['CA', 'AZ', 'NM', 'OK', 'MO', 'IL', 'IN'],
#    'OH': ['CA', 'AZ', 'NM', 'OK', 'MO', 'KY', 'OH'],
#    'WV': ['CA', 'AZ', 'NM', 'OK', 'MO', 'KY', 'WV'],
#    'MI': ['CA', 'AZ', 'NM', 'CO', 'NE', 'IA', 'WI', 'MI'],
#    'FL': ['CA', 'AZ', 'NM', 'OK', 'AR', 'MS', 'AL', 'FL'],
#    'SC': ['CA', 'AZ', 'NM', 'OK', 'AR', 'TN', 'GA', 'SC'],
#    'MD': ['CA', 'AZ', 'NM', 'OK', 'AR', 'TN', 'VA', 'MD'],
#    'PA': ['CA', 'AZ', 'NM', 'OK', 'MO', 'KY', 'OH', 'PA'],
#    'DE': ['CA', 'AZ', 'NM', 'OK', 'AR', 'TN', 'VA', 'MD', 'DE'],
#    'NJ': ['CA', 'AZ', 'NM', 'OK', 'MO', 'KY', 'OH', 'PA', 'NJ'],
#    'NY': ['CA', 'AZ', 'NM', 'OK', 'MO', 'KY', 'OH', 'PA', 'NY'],
#    'CT': ['CA', 'AZ', 'NM', 'OK', 'MO', 'KY', 'OH', 'PA', 'NY', 'CT'],
#    'MA': ['CA', 'AZ', 'NM', 'OK', 'MO', 'KY', 'OH', 'PA', 'NY', 'MA'],
#    'VT': ['CA', 'AZ', 'NM', 'OK', 'MO', 'KY', 'OH', 'PA', 'NY', 'VT'],
#    'RI': ['CA', 'AZ', 'NM', 'OK', 'MO', 'KY', 'OH', 'PA', 'NY', 'CT', 'RI'],
#    'NH': ['CA', 'AZ', 'NM', 'OK', 'MO', 'KY', 'OH', 'PA', 'NY', 'MA', 'NH'],
#    'ME': ['CA',
#     'AZ',
#     'NM',
#     'OK',
#     'MO',
#     'KY',
#     'OH',
#     'PA',
#     'NY',
#     'MA',
#     'NH',
#     'ME']}),
#  ('CO',
#   {'CO': ['CO'],
#    'KS': ['CO', 'KS'],
#    'NE': ['CO', 'NE'],
#    'NM': ['CO', 'NM'],
#    'OK': ['CO', 'OK'],
#    'UT': ['CO', 'UT'],
#    'WY': ['CO', 'WY'],
#    'MO': ['CO', 'KS', 'MO'],
#    'IA': ['CO', 'NE', 'IA'],
#    'SD': ['CO', 'NE', 'SD'],
#    'AZ': ['CO', 'NM', 'AZ'],
#    'TX': ['CO', 'NM', 'TX'],
#    'AR': ['CO', 'OK', 'AR'],
#    'ID': ['CO', 'UT', 'ID'],
#    'NV': ['CO', 'UT', 'NV'],
#    'MT': ['CO', 'WY', 'MT'],
#    'IL': ['CO', 'KS', 'MO', 'IL'],
#    'KY': ['CO', 'KS', 'MO', 'KY'],
#    'TN': ['CO', 'KS', 'MO', 'TN'],
#    'MN': ['CO', 'NE', 'IA', 'MN'],
#    'WI': ['CO', 'NE', 'IA', 'WI'],
#    'ND': ['CO', 'NE', 'SD', 'ND'],
#    'CA': ['CO', 'NM', 'AZ', 'CA'],
#    'LA': ['CO', 'NM', 'TX', 'LA'],
#    'MS': ['CO', 'OK', 'AR', 'MS'],
#    'OR': ['CO', 'UT', 'ID', 'OR'],
#    'WA': ['CO', 'UT', 'ID', 'WA'],
#    'IN': ['CO', 'KS', 'MO', 'IL', 'IN'],
#    'OH': ['CO', 'KS', 'MO', 'KY', 'OH'],
#    'VA': ['CO', 'KS', 'MO', 'KY', 'VA'],
#    'WV': ['CO', 'KS', 'MO', 'KY', 'WV'],
#    'AL': ['CO', 'KS', 'MO', 'TN', 'AL'],
#    'GA': ['CO', 'KS', 'MO', 'TN', 'GA'],
#    'NC': ['CO', 'KS', 'MO', 'TN', 'NC'],
#    'MI': ['CO', 'NE', 'IA', 'WI', 'MI'],
#    'PA': ['CO', 'KS', 'MO', 'KY', 'OH', 'PA'],
#    'MD': ['CO', 'KS', 'MO', 'KY', 'VA', 'MD'],
#    'FL': ['CO', 'KS', 'MO', 'TN', 'AL', 'FL'],
#    'SC': ['CO', 'KS', 'MO', 'TN', 'GA', 'SC'],
#    'DE': ['CO', 'KS', 'MO', 'KY', 'OH', 'PA', 'DE'],
#    'NJ': ['CO', 'KS', 'MO', 'KY', 'OH', 'PA', 'NJ'],
#    'NY': ['CO', 'KS', 'MO', 'KY', 'OH', 'PA', 'NY'],
#    'CT': ['CO', 'KS', 'MO', 'KY', 'OH', 'PA', 'NY', 'CT'],
#    'MA': ['CO', 'KS', 'MO', 'KY', 'OH', 'PA', 'NY', 'MA'],
#    'VT': ['CO', 'KS', 'MO', 'KY', 'OH', 'PA', 'NY', 'VT'],
#    'RI': ['CO', 'KS', 'MO', 'KY', 'OH', 'PA', 'NY', 'CT', 'RI'],
#    'NH': ['CO', 'KS', 'MO', 'KY', 'OH', 'PA', 'NY', 'MA', 'NH'],
#    'ME': ['CO', 'KS', 'MO', 'KY', 'OH', 'PA', 'NY', 'MA', 'NH', 'ME']}),
#  ('CT',
#   {'CT': ['CT'],
#    'MA': ['CT', 'MA'],
#    'NY': ['CT', 'NY'],
#    'RI': ['CT', 'RI'],
#    'NH': ['CT', 'MA', 'NH'],
#    'VT': ['CT', 'MA', 'VT'],
#    'NJ': ['CT', 'NY', 'PA', 'NJ'],
#    'PA': ['CT', 'NY', 'PA'],
#    'DE': ['CT', 'NY', 'PA', 'DE'],
#    'MD': ['CT', 'NY', 'PA', 'MD'],
#    'OH': ['CT', 'NY', 'PA', 'OH'],
#    'WV': ['CT', 'NY', 'PA', 'WV'],
#    'VA': ['CT', 'NY', 'PA', 'MD', 'VA'],
#    'IN': ['CT', 'NY', 'PA', 'OH', 'IN'],
#    'KY': ['CT', 'NY', 'PA', 'OH', 'KY'],
#    'MI': ['CT', 'NY', 'PA', 'OH', 'MI'],
#    'NC': ['CT', 'NY', 'PA', 'MD', 'VA', 'NC'],
#    'TN': ['CT', 'NY', 'PA', 'MD', 'VA', 'TN'],
#    'IL': ['CT', 'NY', 'PA', 'OH', 'IN', 'IL'],
#    'MO': ['CT', 'NY', 'PA', 'OH', 'KY', 'MO'],
#    'WI': ['CT', 'NY', 'PA', 'OH', 'MI', 'WI'],
#    'GA': ['CT', 'NY', 'PA', 'MD', 'VA', 'NC', 'GA'],
#    'SC': ['CT', 'NY', 'PA', 'MD', 'VA', 'NC', 'SC'],
#    'AL': ['CT', 'NY', 'PA', 'MD', 'VA', 'TN', 'AL'],
#    'AR': ['CT', 'NY', 'PA', 'MD', 'VA', 'TN', 'AR'],
#    'MS': ['CT', 'NY', 'PA', 'MD', 'VA', 'TN', 'MS'],
#    'IA': ['CT', 'NY', 'PA', 'OH', 'IN', 'IL', 'IA'],
#    'KS': ['CT', 'NY', 'PA', 'OH', 'KY', 'MO', 'KS'],
#    'NE': ['CT', 'NY', 'PA', 'OH', 'KY', 'MO', 'NE'],
#    'OK': ['CT', 'NY', 'PA', 'OH', 'KY', 'MO', 'OK'],
#    'MN': ['CT', 'NY', 'PA', 'OH', 'MI', 'WI', 'MN'],
#    'FL': ['CT', 'NY', 'PA', 'MD', 'VA', 'NC', 'GA', 'FL'],
#    'LA': ['CT', 'NY', 'PA', 'MD', 'VA', 'TN', 'AR', 'LA'],
#    'TX': ['CT', 'NY', 'PA', 'MD', 'VA', 'TN', 'AR', 'TX'],
#    'SD': ['CT', 'NY', 'PA', 'OH', 'IN', 'IL', 'IA', 'SD'],
#    'CO': ['CT', 'NY', 'PA', 'OH', 'KY', 'MO', 'KS', 'CO'],
#    'WY': ['CT', 'NY', 'PA', 'OH', 'KY', 'MO', 'NE', 'WY'],
#    'NM': ['CT', 'NY', 'PA', 'OH', 'KY', 'MO', 'OK', 'NM'],
#    'ND': ['CT', 'NY', 'PA', 'OH', 'MI', 'WI', 'MN', 'ND'],
#    'MT': ['CT', 'NY', 'PA', 'OH', 'IN', 'IL', 'IA', 'SD', 'MT'],
#    'UT': ['CT', 'NY', 'PA', 'OH', 'KY', 'MO', 'KS', 'CO', 'UT'],
#    'ID': ['CT', 'NY', 'PA', 'OH', 'KY', 'MO', 'NE', 'WY', 'ID'],
#    'AZ': ['CT', 'NY', 'PA', 'OH', 'KY', 'MO', 'OK', 'NM', 'AZ'],
#    'NV': ['CT', 'NY', 'PA', 'OH', 'KY', 'MO', 'KS', 'CO', 'UT', 'NV'],
#    'OR': ['CT', 'NY', 'PA', 'OH', 'KY', 'MO', 'NE', 'WY', 'ID', 'OR'],
#    'WA': ['CT', 'NY', 'PA', 'OH', 'KY', 'MO', 'NE', 'WY', 'ID', 'WA'],
#    'CA': ['CT', 'NY', 'PA', 'OH', 'KY', 'MO', 'OK', 'NM', 'AZ', 'CA'],
#    'ME': ['CT', 'MA', 'NH', 'ME']}),
#  ('DE',
#   {'DE': ['DE'],
#    'MD': ['DE', 'MD'],
#    'NJ': ['DE', 'NJ'],
#    'PA': ['DE', 'PA'],
#    'VA': ['DE', 'MD', 'VA'],
#    'WV': ['DE', 'MD', 'WV'],
#    'NY': ['DE', 'PA', 'NY'],
#    'OH': ['DE', 'PA', 'OH'],
#    'KY': ['DE', 'MD', 'VA', 'KY'],
#    'NC': ['DE', 'MD', 'VA', 'NC'],
#    'TN': ['DE', 'MD', 'VA', 'TN'],
#    'CT': ['DE', 'PA', 'NY', 'CT'],
#    'MA': ['DE', 'PA', 'NY', 'MA'],
#    'VT': ['DE', 'PA', 'NY', 'VT'],
#    'IN': ['DE', 'PA', 'OH', 'IN'],
#    'MI': ['DE', 'PA', 'OH', 'MI'],
#    'IL': ['DE', 'MD', 'VA', 'KY', 'IL'],
#    'MO': ['DE', 'MD', 'VA', 'KY', 'MO'],
#    'GA': ['DE', 'MD', 'VA', 'NC', 'GA'],
#    'SC': ['DE', 'MD', 'VA', 'NC', 'SC'],
#    'AL': ['DE', 'MD', 'VA', 'TN', 'AL'],
#    'AR': ['DE', 'MD', 'VA', 'TN', 'AR'],
#    'MS': ['DE', 'MD', 'VA', 'TN', 'MS'],
#    'WI': ['DE', 'PA', 'OH', 'MI', 'WI'],
#    'IA': ['DE', 'MD', 'VA', 'KY', 'IL', 'IA'],
#    'KS': ['DE', 'MD', 'VA', 'KY', 'MO', 'KS'],
#    'NE': ['DE', 'MD', 'VA', 'KY', 'MO', 'NE'],
#    'OK': ['DE', 'MD', 'VA', 'KY', 'MO', 'OK'],
#    'FL': ['DE', 'MD', 'VA', 'NC', 'GA', 'FL'],
#    'LA': ['DE', 'MD', 'VA', 'TN', 'AR', 'LA'],
#    'TX': ['DE', 'MD', 'VA', 'TN', 'AR', 'TX'],
#    'MN': ['DE', 'PA', 'OH', 'MI', 'WI', 'MN'],
#    'SD': ['DE', 'MD', 'VA', 'KY', 'IL', 'IA', 'SD'],
#    'CO': ['DE', 'MD', 'VA', 'KY', 'MO', 'KS', 'CO'],
#    'WY': ['DE', 'MD', 'VA', 'KY', 'MO', 'NE', 'WY'],
#    'NM': ['DE', 'MD', 'VA', 'KY', 'MO', 'OK', 'NM'],
#    'ND': ['DE', 'PA', 'OH', 'MI', 'WI', 'MN', 'ND'],
#    'MT': ['DE', 'MD', 'VA', 'KY', 'IL', 'IA', 'SD', 'MT'],
#    'UT': ['DE', 'MD', 'VA', 'KY', 'MO', 'KS', 'CO', 'UT'],
#    'ID': ['DE', 'MD', 'VA', 'KY', 'MO', 'NE', 'WY', 'ID'],
#    'AZ': ['DE', 'MD', 'VA', 'KY', 'MO', 'OK', 'NM', 'AZ'],
#    'NV': ['DE', 'MD', 'VA', 'KY', 'MO', 'KS', 'CO', 'UT', 'NV'],
#    'OR': ['DE', 'MD', 'VA', 'KY', 'MO', 'NE', 'WY', 'ID', 'OR'],
#    'WA': ['DE', 'MD', 'VA', 'KY', 'MO', 'NE', 'WY', 'ID', 'WA'],
#    'CA': ['DE', 'MD', 'VA', 'KY', 'MO', 'OK', 'NM', 'AZ', 'CA'],
#    'RI': ['DE', 'PA', 'NY', 'CT', 'RI'],
#    'NH': ['DE', 'PA', 'NY', 'MA', 'NH'],
#    'ME': ['DE', 'PA', 'NY', 'MA', 'NH', 'ME']}),
#  ('FL',
#   {'FL': ['FL'],
#    'AL': ['FL', 'AL'],
#    'GA': ['FL', 'GA'],
#    'MS': ['FL', 'AL', 'MS'],
#    'TN': ['FL', 'AL', 'TN'],
#    'NC': ['FL', 'GA', 'NC'],
#    'SC': ['FL', 'GA', 'SC'],
#    'AR': ['FL', 'AL', 'MS', 'AR'],
#    'LA': ['FL', 'AL', 'MS', 'LA'],
#    'KY': ['FL', 'AL', 'TN', 'KY'],
#    'MO': ['FL', 'AL', 'TN', 'MO'],
#    'VA': ['FL', 'AL', 'TN', 'VA'],
#    'OK': ['FL', 'AL', 'MS', 'AR', 'OK'],
#    'TX': ['FL', 'AL', 'MS', 'AR', 'TX'],
#    'IL': ['FL', 'AL', 'TN', 'KY', 'IL'],
#    'IN': ['FL', 'AL', 'TN', 'KY', 'IN'],
#    'OH': ['FL', 'AL', 'TN', 'KY', 'OH'],
#    'WV': ['FL', 'AL', 'TN', 'KY', 'WV'],
#    'IA': ['FL', 'AL', 'TN', 'MO', 'IA'],
#    'KS': ['FL', 'AL', 'TN', 'MO', 'KS'],
#    'NE': ['FL', 'AL', 'TN', 'MO', 'NE'],
#    'MD': ['FL', 'AL', 'TN', 'VA', 'MD'],
#    'CO': ['FL', 'AL', 'MS', 'AR', 'OK', 'CO'],
#    'NM': ['FL', 'AL', 'MS', 'AR', 'OK', 'NM'],
#    'WI': ['FL', 'AL', 'TN', 'KY', 'IL', 'WI'],
#    'MI': ['FL', 'AL', 'TN', 'KY', 'IN', 'MI'],
#    'PA': ['FL', 'AL', 'TN', 'KY', 'OH', 'PA'],
#    'MN': ['FL', 'AL', 'TN', 'MO', 'IA', 'MN'],
#    'SD': ['FL', 'AL', 'TN', 'MO', 'IA', 'SD'],
#    'WY': ['FL', 'AL', 'TN', 'MO', 'NE', 'WY'],
#    'DE': ['FL', 'AL', 'TN', 'VA', 'MD', 'DE'],
#    'UT': ['FL', 'AL', 'MS', 'AR', 'OK', 'CO', 'UT'],
#    'AZ': ['FL', 'AL', 'MS', 'AR', 'OK', 'NM', 'AZ'],
#    'NJ': ['FL', 'AL', 'TN', 'KY', 'OH', 'PA', 'NJ'],
#    'NY': ['FL', 'AL', 'TN', 'KY', 'OH', 'PA', 'NY'],
#    'ND': ['FL', 'AL', 'TN', 'MO', 'IA', 'MN', 'ND'],
#    'MT': ['FL', 'AL', 'TN', 'MO', 'IA', 'SD', 'MT'],
#    'ID': ['FL', 'AL', 'TN', 'MO', 'NE', 'WY', 'ID'],
#    'NV': ['FL', 'AL', 'MS', 'AR', 'OK', 'CO', 'UT', 'NV'],
#    'CA': ['FL', 'AL', 'MS', 'AR', 'OK', 'NM', 'AZ', 'CA'],
#    'CT': ['FL', 'AL', 'TN', 'KY', 'OH', 'PA', 'NY', 'CT'],
#    'MA': ['FL', 'AL', 'TN', 'KY', 'OH', 'PA', 'NY', 'MA'],
#    'VT': ['FL', 'AL', 'TN', 'KY', 'OH', 'PA', 'NY', 'VT'],
#    'OR': ['FL', 'AL', 'TN', 'MO', 'NE', 'WY', 'ID', 'OR'],
#    'WA': ['FL', 'AL', 'TN', 'MO', 'NE', 'WY', 'ID', 'WA'],
#    'RI': ['FL', 'AL', 'TN', 'KY', 'OH', 'PA', 'NY', 'CT', 'RI'],
#    'NH': ['FL', 'AL', 'TN', 'KY', 'OH', 'PA', 'NY', 'MA', 'NH'],
#    'ME': ['FL', 'AL', 'TN', 'KY', 'OH', 'PA', 'NY', 'MA', 'NH', 'ME']}),
#  ('GA',
#   {'GA': ['GA'],
#    'AL': ['GA', 'AL'],
#    'FL': ['GA', 'FL'],
#    'NC': ['GA', 'NC'],
#    'SC': ['GA', 'SC'],
#    'TN': ['GA', 'TN'],
#    'MS': ['GA', 'AL', 'MS'],
#    'VA': ['GA', 'NC', 'VA'],
#    'AR': ['GA', 'TN', 'AR'],
#    'KY': ['GA', 'TN', 'KY'],
#    'MO': ['GA', 'TN', 'MO'],
#    'LA': ['GA', 'AL', 'MS', 'LA'],
#    'MD': ['GA', 'NC', 'VA', 'MD'],
#    'WV': ['GA', 'NC', 'VA', 'WV'],
#    'OK': ['GA', 'TN', 'AR', 'OK'],
#    'TX': ['GA', 'TN', 'AR', 'TX'],
#    'IL': ['GA', 'TN', 'KY', 'IL'],
#    'IN': ['GA', 'TN', 'KY', 'IN'],
#    'OH': ['GA', 'TN', 'KY', 'OH'],
#    'IA': ['GA', 'TN', 'MO', 'IA'],
#    'KS': ['GA', 'TN', 'MO', 'KS'],
#    'NE': ['GA', 'TN', 'MO', 'NE'],
#    'DE': ['GA', 'NC', 'VA', 'MD', 'DE'],
#    'PA': ['GA', 'NC', 'VA', 'MD', 'PA'],
#    'CO': ['GA', 'TN', 'AR', 'OK', 'CO'],
#    'NM': ['GA', 'TN', 'AR', 'OK', 'NM'],
#    'WI': ['GA', 'TN', 'KY', 'IL', 'WI'],
#    'MI': ['GA', 'TN', 'KY', 'IN', 'MI'],
#    'MN': ['GA', 'TN', 'MO', 'IA', 'MN'],
#    'SD': ['GA', 'TN', 'MO', 'IA', 'SD'],
#    'WY': ['GA', 'TN', 'MO', 'NE', 'WY'],
#    'NJ': ['GA', 'NC', 'VA', 'MD', 'PA', 'NJ'],
#    'NY': ['GA', 'NC', 'VA', 'MD', 'PA', 'NY'],
#    'UT': ['GA', 'TN', 'AR', 'OK', 'CO', 'UT'],
#    'AZ': ['GA', 'TN', 'AR', 'OK', 'NM', 'AZ'],
#    'ND': ['GA', 'TN', 'MO', 'IA', 'MN', 'ND'],
#    'MT': ['GA', 'TN', 'MO', 'IA', 'SD', 'MT'],
#    'ID': ['GA', 'TN', 'MO', 'NE', 'WY', 'ID'],
#    'CT': ['GA', 'NC', 'VA', 'MD', 'PA', 'NY', 'CT'],
#    'MA': ['GA', 'NC', 'VA', 'MD', 'PA', 'NY', 'MA'],
#    'VT': ['GA', 'NC', 'VA', 'MD', 'PA', 'NY', 'VT'],
#    'NV': ['GA', 'TN', 'AR', 'OK', 'CO', 'UT', 'NV'],
#    'CA': ['GA', 'TN', 'AR', 'OK', 'NM', 'AZ', 'CA'],
#    'OR': ['GA', 'TN', 'MO', 'NE', 'WY', 'ID', 'OR'],
#    'WA': ['GA', 'TN', 'MO', 'NE', 'WY', 'ID', 'WA'],
#    'RI': ['GA', 'NC', 'VA', 'MD', 'PA', 'NY', 'CT', 'RI'],
#    'NH': ['GA', 'NC', 'VA', 'MD', 'PA', 'NY', 'MA', 'NH'],
#    'ME': ['GA', 'NC', 'VA', 'MD', 'PA', 'NY', 'MA', 'NH', 'ME']}),
#  ('HI', {'HI': ['HI']}),
#  ('ID',
#   {'ID': ['ID'],
#    'MT': ['ID', 'MT'],
#    'NV': ['ID', 'NV'],
#    'OR': ['ID', 'OR'],
#    'UT': ['ID', 'UT'],
#    'WA': ['ID', 'WA'],
#    'WY': ['ID', 'WY'],
#    'ND': ['ID', 'MT', 'ND'],
#    'SD': ['ID', 'MT', 'SD'],
#    'AZ': ['ID', 'NV', 'AZ'],
#    'CA': ['ID', 'NV', 'CA'],
#    'CO': ['ID', 'UT', 'CO'],
#    'NE': ['ID', 'WY', 'NE'],
#    'MN': ['ID', 'MT', 'ND', 'MN'],
#    'IA': ['ID', 'MT', 'SD', 'IA'],
#    'NM': ['ID', 'NV', 'AZ', 'NM'],
#    'KS': ['ID', 'UT', 'CO', 'KS'],
#    'OK': ['ID', 'UT', 'CO', 'OK'],
#    'MO': ['ID', 'WY', 'NE', 'MO'],
#    'WI': ['ID', 'MT', 'ND', 'MN', 'WI'],
#    'IL': ['ID', 'MT', 'SD', 'IA', 'IL'],
#    'TX': ['ID', 'NV', 'AZ', 'NM', 'TX'],
#    'AR': ['ID', 'UT', 'CO', 'OK', 'AR'],
#    'KY': ['ID', 'WY', 'NE', 'MO', 'KY'],
#    'TN': ['ID', 'WY', 'NE', 'MO', 'TN'],
#    'MI': ['ID', 'MT', 'ND', 'MN', 'WI', 'MI'],
#    'IN': ['ID', 'MT', 'SD', 'IA', 'IL', 'IN'],
#    'LA': ['ID', 'NV', 'AZ', 'NM', 'TX', 'LA'],
#    'MS': ['ID', 'UT', 'CO', 'OK', 'AR', 'MS'],
#    'OH': ['ID', 'WY', 'NE', 'MO', 'KY', 'OH'],
#    'VA': ['ID', 'WY', 'NE', 'MO', 'KY', 'VA'],
#    'WV': ['ID', 'WY', 'NE', 'MO', 'KY', 'WV'],
#    'AL': ['ID', 'WY', 'NE', 'MO', 'TN', 'AL'],
#    'GA': ['ID', 'WY', 'NE', 'MO', 'TN', 'GA'],
#    'NC': ['ID', 'WY', 'NE', 'MO', 'TN', 'NC'],
#    'PA': ['ID', 'WY', 'NE', 'MO', 'KY', 'OH', 'PA'],
#    'MD': ['ID', 'WY', 'NE', 'MO', 'KY', 'VA', 'MD'],
#    'FL': ['ID', 'WY', 'NE', 'MO', 'TN', 'AL', 'FL'],
#    'SC': ['ID', 'WY', 'NE', 'MO', 'TN', 'GA', 'SC'],
#    'DE': ['ID', 'WY', 'NE', 'MO', 'KY', 'OH', 'PA', 'DE'],
#    'NJ': ['ID', 'WY', 'NE', 'MO', 'KY', 'OH', 'PA', 'NJ'],
#    'NY': ['ID', 'WY', 'NE', 'MO', 'KY', 'OH', 'PA', 'NY'],
#    'CT': ['ID', 'WY', 'NE', 'MO', 'KY', 'OH', 'PA', 'NY', 'CT'],
#    'MA': ['ID', 'WY', 'NE', 'MO', 'KY', 'OH', 'PA', 'NY', 'MA'],
#    'VT': ['ID', 'WY', 'NE', 'MO', 'KY', 'OH', 'PA', 'NY', 'VT'],
#    'RI': ['ID', 'WY', 'NE', 'MO', 'KY', 'OH', 'PA', 'NY', 'CT', 'RI'],
#    'NH': ['ID', 'WY', 'NE', 'MO', 'KY', 'OH', 'PA', 'NY', 'MA', 'NH'],
#    'ME': ['ID', 'WY', 'NE', 'MO', 'KY', 'OH', 'PA', 'NY', 'MA', 'NH', 'ME']}),
#  ('IL',
#   {'IL': ['IL'],
#    'IN': ['IL', 'IN'],
#    'IA': ['IL', 'IA'],
#    'KY': ['IL', 'KY'],
#    'MO': ['IL', 'MO'],
#    'WI': ['IL', 'WI'],
#    'MI': ['IL', 'IN', 'MI'],
#    'OH': ['IL', 'IN', 'OH'],
#    'MN': ['IL', 'IA', 'MN'],
#    'NE': ['IL', 'IA', 'NE'],
#    'SD': ['IL', 'IA', 'SD'],
#    'TN': ['IL', 'KY', 'TN'],
#    'VA': ['IL', 'KY', 'VA'],
#    'WV': ['IL', 'KY', 'WV'],
#    'AR': ['IL', 'MO', 'AR'],
#    'KS': ['IL', 'MO', 'KS'],
#    'OK': ['IL', 'MO', 'OK'],
#    'PA': ['IL', 'IN', 'OH', 'PA'],
#    'ND': ['IL', 'IA', 'MN', 'ND'],
#    'CO': ['IL', 'IA', 'NE', 'CO'],
#    'WY': ['IL', 'IA', 'NE', 'WY'],
#    'MT': ['IL', 'IA', 'SD', 'MT'],
#    'AL': ['IL', 'KY', 'TN', 'AL'],
#    'GA': ['IL', 'KY', 'TN', 'GA'],
#    'MS': ['IL', 'KY', 'TN', 'MS'],
#    'NC': ['IL', 'KY', 'TN', 'NC'],
#    'MD': ['IL', 'KY', 'VA', 'MD'],
#    'LA': ['IL', 'MO', 'AR', 'LA'],
#    'TX': ['IL', 'MO', 'AR', 'TX'],
#    'NM': ['IL', 'MO', 'OK', 'NM'],
#    'DE': ['IL', 'IN', 'OH', 'PA', 'DE'],
#    'NJ': ['IL', 'IN', 'OH', 'PA', 'NJ'],
#    'NY': ['IL', 'IN', 'OH', 'PA', 'NY'],
#    'UT': ['IL', 'IA', 'NE', 'CO', 'UT'],
#    'ID': ['IL', 'IA', 'NE', 'WY', 'ID'],
#    'FL': ['IL', 'KY', 'TN', 'AL', 'FL'],
#    'SC': ['IL', 'KY', 'TN', 'GA', 'SC'],
#    'AZ': ['IL', 'MO', 'OK', 'NM', 'AZ'],
#    'CT': ['IL', 'IN', 'OH', 'PA', 'NY', 'CT'],
#    'MA': ['IL', 'IN', 'OH', 'PA', 'NY', 'MA'],
#    'VT': ['IL', 'IN', 'OH', 'PA', 'NY', 'VT'],
#    'NV': ['IL', 'IA', 'NE', 'CO', 'UT', 'NV'],
#    'OR': ['IL', 'IA', 'NE', 'WY', 'ID', 'OR'],
#    'WA': ['IL', 'IA', 'NE', 'WY', 'ID', 'WA'],
#    'CA': ['IL', 'MO', 'OK', 'NM', 'AZ', 'CA'],
#    'RI': ['IL', 'IN', 'OH', 'PA', 'NY', 'CT', 'RI'],
#    'NH': ['IL', 'IN', 'OH', 'PA', 'NY', 'MA', 'NH'],
#    'ME': ['IL', 'IN', 'OH', 'PA', 'NY', 'MA', 'NH', 'ME']}),
#  ('IN',
#   {'IN': ['IN'],
#    'IL': ['IN', 'IL'],
#    'KY': ['IN', 'KY'],
#    'MI': ['IN', 'MI'],
#    'OH': ['IN', 'OH'],
#    'IA': ['IN', 'IL', 'IA'],
#    'MO': ['IN', 'IL', 'MO'],
#    'WI': ['IN', 'IL', 'WI'],
#    'TN': ['IN', 'KY', 'TN'],
#    'VA': ['IN', 'KY', 'VA'],
#    'WV': ['IN', 'KY', 'WV'],
#    'PA': ['IN', 'OH', 'PA'],
#    'MN': ['IN', 'IL', 'IA', 'MN'],
#    'NE': ['IN', 'IL', 'IA', 'NE'],
#    'SD': ['IN', 'IL', 'IA', 'SD'],
#    'AR': ['IN', 'IL', 'MO', 'AR'],
#    'KS': ['IN', 'IL', 'MO', 'KS'],
#    'OK': ['IN', 'IL', 'MO', 'OK'],
#    'AL': ['IN', 'KY', 'TN', 'AL'],
#    'GA': ['IN', 'KY', 'TN', 'GA'],
#    'MS': ['IN', 'KY', 'TN', 'MS'],
#    'NC': ['IN', 'KY', 'TN', 'NC'],
#    'MD': ['IN', 'KY', 'VA', 'MD'],
#    'DE': ['IN', 'OH', 'PA', 'DE'],
#    'NJ': ['IN', 'OH', 'PA', 'NJ'],
#    'NY': ['IN', 'OH', 'PA', 'NY'],
#    'ND': ['IN', 'IL', 'IA', 'MN', 'ND'],
#    'CO': ['IN', 'IL', 'IA', 'NE', 'CO'],
#    'WY': ['IN', 'IL', 'IA', 'NE', 'WY'],
#    'MT': ['IN', 'IL', 'IA', 'SD', 'MT'],
#    'LA': ['IN', 'IL', 'MO', 'AR', 'LA'],
#    'TX': ['IN', 'IL', 'MO', 'AR', 'TX'],
#    'NM': ['IN', 'IL', 'MO', 'OK', 'NM'],
#    'FL': ['IN', 'KY', 'TN', 'AL', 'FL'],
#    'SC': ['IN', 'KY', 'TN', 'GA', 'SC'],
#    'CT': ['IN', 'OH', 'PA', 'NY', 'CT'],
#    'MA': ['IN', 'OH', 'PA', 'NY', 'MA'],
#    'VT': ['IN', 'OH', 'PA', 'NY', 'VT'],
#    'UT': ['IN', 'IL', 'IA', 'NE', 'CO', 'UT'],
#    'ID': ['IN', 'IL', 'IA', 'NE', 'WY', 'ID'],
#    'AZ': ['IN', 'IL', 'MO', 'OK', 'NM', 'AZ'],
#    'NV': ['IN', 'IL', 'IA', 'NE', 'CO', 'UT', 'NV'],
#    'OR': ['IN', 'IL', 'IA', 'NE', 'WY', 'ID', 'OR'],
#    'WA': ['IN', 'IL', 'IA', 'NE', 'WY', 'ID', 'WA'],
#    'CA': ['IN', 'IL', 'MO', 'OK', 'NM', 'AZ', 'CA'],
#    'RI': ['IN', 'OH', 'PA', 'NY', 'CT', 'RI'],
#    'NH': ['IN', 'OH', 'PA', 'NY', 'MA', 'NH'],
#    'ME': ['IN', 'OH', 'PA', 'NY', 'MA', 'NH', 'ME']}),
#  ('IA',
#   {'IA': ['IA'],
#    'IL': ['IA', 'IL'],
#    'MN': ['IA', 'MN'],
#    'MO': ['IA', 'MO'],
#    'NE': ['IA', 'NE'],
#    'SD': ['IA', 'SD'],
#    'WI': ['IA', 'WI'],
#    'IN': ['IA', 'IL', 'IN'],
#    'KY': ['IA', 'IL', 'KY'],
#    'ND': ['IA', 'MN', 'ND'],
#    'AR': ['IA', 'MO', 'AR'],
#    'KS': ['IA', 'MO', 'KS'],
#    'OK': ['IA', 'MO', 'OK'],
#    'TN': ['IA', 'MO', 'TN'],
#    'CO': ['IA', 'NE', 'CO'],
#    'WY': ['IA', 'NE', 'WY'],
#    'MT': ['IA', 'SD', 'MT'],
#    'MI': ['IA', 'WI', 'MI'],
#    'OH': ['IA', 'IL', 'IN', 'OH'],
#    'VA': ['IA', 'IL', 'KY', 'VA'],
#    'WV': ['IA', 'IL', 'KY', 'WV'],
#    'LA': ['IA', 'MO', 'AR', 'LA'],
#    'MS': ['IA', 'MO', 'AR', 'MS'],
#    'TX': ['IA', 'MO', 'AR', 'TX'],
#    'NM': ['IA', 'MO', 'OK', 'NM'],
#    'AL': ['IA', 'MO', 'TN', 'AL'],
#    'GA': ['IA', 'MO', 'TN', 'GA'],
#    'NC': ['IA', 'MO', 'TN', 'NC'],
#    'UT': ['IA', 'NE', 'CO', 'UT'],
#    'ID': ['IA', 'NE', 'WY', 'ID'],
#    'PA': ['IA', 'IL', 'IN', 'OH', 'PA'],
#    'MD': ['IA', 'IL', 'KY', 'VA', 'MD'],
#    'AZ': ['IA', 'MO', 'OK', 'NM', 'AZ'],
#    'FL': ['IA', 'MO', 'TN', 'AL', 'FL'],
#    'SC': ['IA', 'MO', 'TN', 'GA', 'SC'],
#    'NV': ['IA', 'NE', 'CO', 'UT', 'NV'],
#    'OR': ['IA', 'NE', 'WY', 'ID', 'OR'],
#    'WA': ['IA', 'NE', 'WY', 'ID', 'WA'],
#    'DE': ['IA', 'IL', 'IN', 'OH', 'PA', 'DE'],
#    'NJ': ['IA', 'IL', 'IN', 'OH', 'PA', 'NJ'],
#    'NY': ['IA', 'IL', 'IN', 'OH', 'PA', 'NY'],
#    'CA': ['IA', 'MO', 'OK', 'NM', 'AZ', 'CA'],
#    'CT': ['IA', 'IL', 'IN', 'OH', 'PA', 'NY', 'CT'],
#    'MA': ['IA', 'IL', 'IN', 'OH', 'PA', 'NY', 'MA'],
#    'VT': ['IA', 'IL', 'IN', 'OH', 'PA', 'NY', 'VT'],
#    'RI': ['IA', 'IL', 'IN', 'OH', 'PA', 'NY', 'CT', 'RI'],
#    'NH': ['IA', 'IL', 'IN', 'OH', 'PA', 'NY', 'MA', 'NH'],
#    'ME': ['IA', 'IL', 'IN', 'OH', 'PA', 'NY', 'MA', 'NH', 'ME']}),
#  ('KS',
#   {'KS': ['KS'],
#    'CO': ['KS', 'CO'],
#    'MO': ['KS', 'MO'],
#    'NE': ['KS', 'NE'],
#    'OK': ['KS', 'OK'],
#    'NM': ['KS', 'CO', 'NM'],
#    'UT': ['KS', 'CO', 'UT'],
#    'WY': ['KS', 'CO', 'WY'],
#    'AR': ['KS', 'MO', 'AR'],
#    'IL': ['KS', 'MO', 'IL'],
#    'IA': ['KS', 'MO', 'IA'],
#    'KY': ['KS', 'MO', 'KY'],
#    'TN': ['KS', 'MO', 'TN'],
#    'SD': ['KS', 'NE', 'SD'],
#    'TX': ['KS', 'OK', 'TX'],
#    'AZ': ['KS', 'CO', 'NM', 'AZ'],
#    'ID': ['KS', 'CO', 'UT', 'ID'],
#    'NV': ['KS', 'CO', 'UT', 'NV'],
#    'MT': ['KS', 'CO', 'WY', 'MT'],
#    'LA': ['KS', 'MO', 'AR', 'LA'],
#    'MS': ['KS', 'MO', 'AR', 'MS'],
#    'IN': ['KS', 'MO', 'IL', 'IN'],
#    'WI': ['KS', 'MO', 'IL', 'WI'],
#    'MN': ['KS', 'MO', 'IA', 'MN'],
#    'OH': ['KS', 'MO', 'KY', 'OH'],
#    'VA': ['KS', 'MO', 'KY', 'VA'],
#    'WV': ['KS', 'MO', 'KY', 'WV'],
#    'AL': ['KS', 'MO', 'TN', 'AL'],
#    'GA': ['KS', 'MO', 'TN', 'GA'],
#    'NC': ['KS', 'MO', 'TN', 'NC'],
#    'ND': ['KS', 'NE', 'SD', 'ND'],
#    'CA': ['KS', 'CO', 'NM', 'AZ', 'CA'],
#    'OR': ['KS', 'CO', 'UT', 'ID', 'OR'],
#    'WA': ['KS', 'CO', 'UT', 'ID', 'WA'],
#    'MI': ['KS', 'MO', 'IL', 'IN', 'MI'],
#    'PA': ['KS', 'MO', 'KY', 'OH', 'PA'],
#    'MD': ['KS', 'MO', 'KY', 'VA', 'MD'],
#    'FL': ['KS', 'MO', 'TN', 'AL', 'FL'],
#    'SC': ['KS', 'MO', 'TN', 'GA', 'SC'],
#    'DE': ['KS', 'MO', 'KY', 'OH', 'PA', 'DE'],
#    'NJ': ['KS', 'MO', 'KY', 'OH', 'PA', 'NJ'],
#    'NY': ['KS', 'MO', 'KY', 'OH', 'PA', 'NY'],
#    'CT': ['KS', 'MO', 'KY', 'OH', 'PA', 'NY', 'CT'],
#    'MA': ['KS', 'MO', 'KY', 'OH', 'PA', 'NY', 'MA'],
#    'VT': ['KS', 'MO', 'KY', 'OH', 'PA', 'NY', 'VT'],
#    'RI': ['KS', 'MO', 'KY', 'OH', 'PA', 'NY', 'CT', 'RI'],
#    'NH': ['KS', 'MO', 'KY', 'OH', 'PA', 'NY', 'MA', 'NH'],
#    'ME': ['KS', 'MO', 'KY', 'OH', 'PA', 'NY', 'MA', 'NH', 'ME']}),
#  ('KY',
#   {'KY': ['KY'],
#    'IL': ['KY', 'IL'],
#    'IN': ['KY', 'IN'],
#    'MO': ['KY', 'MO'],
#    'OH': ['KY', 'OH'],
#    'TN': ['KY', 'TN'],
#    'VA': ['KY', 'VA'],
#    'WV': ['KY', 'WV'],
#    'IA': ['KY', 'IL', 'IA'],
#    'WI': ['KY', 'IL', 'WI'],
#    'MI': ['KY', 'IN', 'MI'],
#    'AR': ['KY', 'MO', 'AR'],
#    'KS': ['KY', 'MO', 'KS'],
#    'NE': ['KY', 'MO', 'NE'],
#    'OK': ['KY', 'MO', 'OK'],
#    'PA': ['KY', 'OH', 'PA'],
#    'AL': ['KY', 'TN', 'AL'],
#    'GA': ['KY', 'TN', 'GA'],
#    'MS': ['KY', 'TN', 'MS'],
#    'NC': ['KY', 'TN', 'NC'],
#    'MD': ['KY', 'VA', 'MD'],
#    'MN': ['KY', 'IL', 'IA', 'MN'],
#    'SD': ['KY', 'IL', 'IA', 'SD'],
#    'LA': ['KY', 'MO', 'AR', 'LA'],
#    'TX': ['KY', 'MO', 'AR', 'TX'],
#    'CO': ['KY', 'MO', 'KS', 'CO'],
#    'WY': ['KY', 'MO', 'NE', 'WY'],
#    'NM': ['KY', 'MO', 'OK', 'NM'],
#    'DE': ['KY', 'OH', 'PA', 'DE'],
#    'NJ': ['KY', 'OH', 'PA', 'NJ'],
#    'NY': ['KY', 'OH', 'PA', 'NY'],
#    'FL': ['KY', 'TN', 'AL', 'FL'],
#    'SC': ['KY', 'TN', 'GA', 'SC'],
#    'ND': ['KY', 'IL', 'IA', 'MN', 'ND'],
#    'MT': ['KY', 'IL', 'IA', 'SD', 'MT'],
#    'UT': ['KY', 'MO', 'KS', 'CO', 'UT'],
#    'ID': ['KY', 'MO', 'NE', 'WY', 'ID'],
#    'AZ': ['KY', 'MO', 'OK', 'NM', 'AZ'],
#    'CT': ['KY', 'OH', 'PA', 'NY', 'CT'],
#    'MA': ['KY', 'OH', 'PA', 'NY', 'MA'],
#    'VT': ['KY', 'OH', 'PA', 'NY', 'VT'],
#    'NV': ['KY', 'MO', 'KS', 'CO', 'UT', 'NV'],
#    'OR': ['KY', 'MO', 'NE', 'WY', 'ID', 'OR'],
#    'WA': ['KY', 'MO', 'NE', 'WY', 'ID', 'WA'],
#    'CA': ['KY', 'MO', 'OK', 'NM', 'AZ', 'CA'],
#    'RI': ['KY', 'OH', 'PA', 'NY', 'CT', 'RI'],
#    'NH': ['KY', 'OH', 'PA', 'NY', 'MA', 'NH'],
#    'ME': ['KY', 'OH', 'PA', 'NY', 'MA', 'NH', 'ME']}),
#  ('LA',
#   {'LA': ['LA'],
#    'AR': ['LA', 'AR'],
#    'MS': ['LA', 'MS'],
#    'TX': ['LA', 'TX'],
#    'MO': ['LA', 'AR', 'MO'],
#    'OK': ['LA', 'AR', 'OK'],
#    'TN': ['LA', 'AR', 'TN'],
#    'AL': ['LA', 'MS', 'AL'],
#    'NM': ['LA', 'TX', 'NM'],
#    'IL': ['LA', 'AR', 'MO', 'IL'],
#    'IA': ['LA', 'AR', 'MO', 'IA'],
#    'KS': ['LA', 'AR', 'MO', 'KS'],
#    'KY': ['LA', 'AR', 'MO', 'KY'],
#    'NE': ['LA', 'AR', 'MO', 'NE'],
#    'CO': ['LA', 'AR', 'OK', 'CO'],
#    'GA': ['LA', 'AR', 'TN', 'GA'],
#    'NC': ['LA', 'AR', 'TN', 'NC'],
#    'VA': ['LA', 'AR', 'TN', 'VA'],
#    'FL': ['LA', 'MS', 'AL', 'FL'],
#    'AZ': ['LA', 'TX', 'NM', 'AZ'],
#    'IN': ['LA', 'AR', 'MO', 'IL', 'IN'],
#    'WI': ['LA', 'AR', 'MO', 'IL', 'WI'],
#    'MN': ['LA', 'AR', 'MO', 'IA', 'MN'],
#    'SD': ['LA', 'AR', 'MO', 'IA', 'SD'],
#    'OH': ['LA', 'AR', 'MO', 'KY', 'OH'],
#    'WV': ['LA', 'AR', 'MO', 'KY', 'WV'],
#    'WY': ['LA', 'AR', 'MO', 'NE', 'WY'],
#    'UT': ['LA', 'AR', 'OK', 'CO', 'UT'],
#    'SC': ['LA', 'AR', 'TN', 'GA', 'SC'],
#    'MD': ['LA', 'AR', 'TN', 'VA', 'MD'],
#    'CA': ['LA', 'TX', 'NM', 'AZ', 'CA'],
#    'NV': ['LA', 'TX', 'NM', 'AZ', 'NV'],
#    'MI': ['LA', 'AR', 'MO', 'IL', 'IN', 'MI'],
#    'ND': ['LA', 'AR', 'MO', 'IA', 'MN', 'ND'],
#    'MT': ['LA', 'AR', 'MO', 'IA', 'SD', 'MT'],
#    'PA': ['LA', 'AR', 'MO', 'KY', 'OH', 'PA'],
#    'ID': ['LA', 'AR', 'MO', 'NE', 'WY', 'ID'],
#    'DE': ['LA', 'AR', 'TN', 'VA', 'MD', 'DE'],
#    'OR': ['LA', 'TX', 'NM', 'AZ', 'CA', 'OR'],
#    'NJ': ['LA', 'AR', 'MO', 'KY', 'OH', 'PA', 'NJ'],
#    'NY': ['LA', 'AR', 'MO', 'KY', 'OH', 'PA', 'NY'],
#    'WA': ['LA', 'AR', 'MO', 'NE', 'WY', 'ID', 'WA'],
#    'CT': ['LA', 'AR', 'MO', 'KY', 'OH', 'PA', 'NY', 'CT'],
#    'MA': ['LA', 'AR', 'MO', 'KY', 'OH', 'PA', 'NY', 'MA'],
#    'VT': ['LA', 'AR', 'MO', 'KY', 'OH', 'PA', 'NY', 'VT'],
#    'RI': ['LA', 'AR', 'MO', 'KY', 'OH', 'PA', 'NY', 'CT', 'RI'],
#    'NH': ['LA', 'AR', 'MO', 'KY', 'OH', 'PA', 'NY', 'MA', 'NH'],
#    'ME': ['LA', 'AR', 'MO', 'KY', 'OH', 'PA', 'NY', 'MA', 'NH', 'ME']}),
#  ('ME',
#   {'ME': ['ME'],
#    'NH': ['ME', 'NH'],
#    'MA': ['ME', 'NH', 'MA'],
#    'VT': ['ME', 'NH', 'VT'],
#    'CT': ['ME', 'NH', 'MA', 'CT'],
#    'NY': ['ME', 'NH', 'MA', 'NY'],
#    'RI': ['ME', 'NH', 'MA', 'RI'],
#    'NJ': ['ME', 'NH', 'MA', 'NY', 'PA', 'NJ'],
#    'PA': ['ME', 'NH', 'MA', 'NY', 'PA'],
#    'DE': ['ME', 'NH', 'MA', 'NY', 'PA', 'DE'],
#    'MD': ['ME', 'NH', 'MA', 'NY', 'PA', 'MD'],
#    'OH': ['ME', 'NH', 'MA', 'NY', 'PA', 'OH'],
#    'WV': ['ME', 'NH', 'MA', 'NY', 'PA', 'WV'],
#    'VA': ['ME', 'NH', 'MA', 'NY', 'PA', 'MD', 'VA'],
#    'IN': ['ME', 'NH', 'MA', 'NY', 'PA', 'OH', 'IN'],
#    'KY': ['ME', 'NH', 'MA', 'NY', 'PA', 'OH', 'KY'],
#    'MI': ['ME', 'NH', 'MA', 'NY', 'PA', 'OH', 'MI'],
#    'NC': ['ME', 'NH', 'MA', 'NY', 'PA', 'MD', 'VA', 'NC'],
#    'TN': ['ME', 'NH', 'MA', 'NY', 'PA', 'MD', 'VA', 'TN'],
#    'IL': ['ME', 'NH', 'MA', 'NY', 'PA', 'OH', 'IN', 'IL'],
#    'MO': ['ME', 'NH', 'MA', 'NY', 'PA', 'OH', 'KY', 'MO'],
#    'WI': ['ME', 'NH', 'MA', 'NY', 'PA', 'OH', 'MI', 'WI'],
#    'GA': ['ME', 'NH', 'MA', 'NY', 'PA', 'MD', 'VA', 'NC', 'GA'],
#    'SC': ['ME', 'NH', 'MA', 'NY', 'PA', 'MD', 'VA', 'NC', 'SC'],
#    'AL': ['ME', 'NH', 'MA', 'NY', 'PA', 'MD', 'VA', 'TN', 'AL'],
#    'AR': ['ME', 'NH', 'MA', 'NY', 'PA', 'MD', 'VA', 'TN', 'AR'],
#    'MS': ['ME', 'NH', 'MA', 'NY', 'PA', 'MD', 'VA', 'TN', 'MS'],
#    'IA': ['ME', 'NH', 'MA', 'NY', 'PA', 'OH', 'IN', 'IL', 'IA'],
#    'KS': ['ME', 'NH', 'MA', 'NY', 'PA', 'OH', 'KY', 'MO', 'KS'],
#    'NE': ['ME', 'NH', 'MA', 'NY', 'PA', 'OH', 'KY', 'MO', 'NE'],
#    'OK': ['ME', 'NH', 'MA', 'NY', 'PA', 'OH', 'KY', 'MO', 'OK'],
#    'MN': ['ME', 'NH', 'MA', 'NY', 'PA', 'OH', 'MI', 'WI', 'MN'],
#    'FL': ['ME', 'NH', 'MA', 'NY', 'PA', 'MD', 'VA', 'NC', 'GA', 'FL'],
#    'LA': ['ME', 'NH', 'MA', 'NY', 'PA', 'MD', 'VA', 'TN', 'AR', 'LA'],
#    'TX': ['ME', 'NH', 'MA', 'NY', 'PA', 'MD', 'VA', 'TN', 'AR', 'TX'],
#    'SD': ['ME', 'NH', 'MA', 'NY', 'PA', 'OH', 'IN', 'IL', 'IA', 'SD'],
#    'CO': ['ME', 'NH', 'MA', 'NY', 'PA', 'OH', 'KY', 'MO', 'KS', 'CO'],
#    'WY': ['ME', 'NH', 'MA', 'NY', 'PA', 'OH', 'KY', 'MO', 'NE', 'WY'],
#    'NM': ['ME', 'NH', 'MA', 'NY', 'PA', 'OH', 'KY', 'MO', 'OK', 'NM'],
#    'ND': ['ME', 'NH', 'MA', 'NY', 'PA', 'OH', 'MI', 'WI', 'MN', 'ND'],
#    'MT': ['ME', 'NH', 'MA', 'NY', 'PA', 'OH', 'IN', 'IL', 'IA', 'SD', 'MT'],
#    'UT': ['ME', 'NH', 'MA', 'NY', 'PA', 'OH', 'KY', 'MO', 'KS', 'CO', 'UT'],
#    'ID': ['ME', 'NH', 'MA', 'NY', 'PA', 'OH', 'KY', 'MO', 'NE', 'WY', 'ID'],
#    'AZ': ['ME', 'NH', 'MA', 'NY', 'PA', 'OH', 'KY', 'MO', 'OK', 'NM', 'AZ'],
#    'NV': ['ME',
#     'NH',
#     'MA',
#     'NY',
#     'PA',
#     'OH',
#     'KY',
#     'MO',
#     'KS',
#     'CO',
#     'UT',
#     'NV'],
#    'OR': ['ME',
#     'NH',
#     'MA',
#     'NY',
#     'PA',
#     'OH',
#     'KY',
#     'MO',
#     'NE',
#     'WY',
#     'ID',
#     'OR'],
#    'WA': ['ME',
#     'NH',
#     'MA',
#     'NY',
#     'PA',
#     'OH',
#     'KY',
#     'MO',
#     'NE',
#     'WY',
#     'ID',
#     'WA'],
#    'CA': ['ME',
#     'NH',
#     'MA',
#     'NY',
#     'PA',
#     'OH',
#     'KY',
#     'MO',
#     'OK',
#     'NM',
#     'AZ',
#     'CA']}),
#  ('MD',
#   {'MD': ['MD'],
#    'DE': ['MD', 'DE'],
#    'PA': ['MD', 'PA'],
#    'VA': ['MD', 'VA'],
#    'WV': ['MD', 'WV'],
#    'NJ': ['MD', 'PA', 'NJ'],
#    'NY': ['MD', 'PA', 'NY'],
#    'OH': ['MD', 'PA', 'OH'],
#    'KY': ['MD', 'VA', 'KY'],
#    'NC': ['MD', 'VA', 'NC'],
#    'TN': ['MD', 'VA', 'TN'],
#    'CT': ['MD', 'PA', 'NY', 'CT'],
#    'MA': ['MD', 'PA', 'NY', 'MA'],
#    'VT': ['MD', 'PA', 'NY', 'VT'],
#    'IN': ['MD', 'PA', 'OH', 'IN'],
#    'MI': ['MD', 'PA', 'OH', 'MI'],
#    'IL': ['MD', 'VA', 'KY', 'IL'],
#    'MO': ['MD', 'VA', 'KY', 'MO'],
#    'GA': ['MD', 'VA', 'NC', 'GA'],
#    'SC': ['MD', 'VA', 'NC', 'SC'],
#    'AL': ['MD', 'VA', 'TN', 'AL'],
#    'AR': ['MD', 'VA', 'TN', 'AR'],
#    'MS': ['MD', 'VA', 'TN', 'MS'],
#    'WI': ['MD', 'PA', 'OH', 'MI', 'WI'],
#    'IA': ['MD', 'VA', 'KY', 'IL', 'IA'],
#    'KS': ['MD', 'VA', 'KY', 'MO', 'KS'],
#    'NE': ['MD', 'VA', 'KY', 'MO', 'NE'],
#    'OK': ['MD', 'VA', 'KY', 'MO', 'OK'],
#    'FL': ['MD', 'VA', 'NC', 'GA', 'FL'],
#    'LA': ['MD', 'VA', 'TN', 'AR', 'LA'],
#    'TX': ['MD', 'VA', 'TN', 'AR', 'TX'],
#    'MN': ['MD', 'PA', 'OH', 'MI', 'WI', 'MN'],
#    'SD': ['MD', 'VA', 'KY', 'IL', 'IA', 'SD'],
#    'CO': ['MD', 'VA', 'KY', 'MO', 'KS', 'CO'],
#    'WY': ['MD', 'VA', 'KY', 'MO', 'NE', 'WY'],
#    'NM': ['MD', 'VA', 'KY', 'MO', 'OK', 'NM'],
#    'ND': ['MD', 'PA', 'OH', 'MI', 'WI', 'MN', 'ND'],
#    'MT': ['MD', 'VA', 'KY', 'IL', 'IA', 'SD', 'MT'],
#    'UT': ['MD', 'VA', 'KY', 'MO', 'KS', 'CO', 'UT'],
#    'ID': ['MD', 'VA', 'KY', 'MO', 'NE', 'WY', 'ID'],
#    'AZ': ['MD', 'VA', 'KY', 'MO', 'OK', 'NM', 'AZ'],
#    'NV': ['MD', 'VA', 'KY', 'MO', 'KS', 'CO', 'UT', 'NV'],
#    'OR': ['MD', 'VA', 'KY', 'MO', 'NE', 'WY', 'ID', 'OR'],
#    'WA': ['MD', 'VA', 'KY', 'MO', 'NE', 'WY', 'ID', 'WA'],
#    'CA': ['MD', 'VA', 'KY', 'MO', 'OK', 'NM', 'AZ', 'CA'],
#    'RI': ['MD', 'PA', 'NY', 'CT', 'RI'],
#    'NH': ['MD', 'PA', 'NY', 'MA', 'NH'],
#    'ME': ['MD', 'PA', 'NY', 'MA', 'NH', 'ME']}),
#  ('MA',
#   {'MA': ['MA'],
#    'CT': ['MA', 'CT'],
#    'NH': ['MA', 'NH'],
#    'NY': ['MA', 'NY'],
#    'RI': ['MA', 'RI'],
#    'VT': ['MA', 'VT'],
#    'ME': ['MA', 'NH', 'ME'],
#    'NJ': ['MA', 'NY', 'PA', 'NJ'],
#    'PA': ['MA', 'NY', 'PA'],
#    'DE': ['MA', 'NY', 'PA', 'DE'],
#    'MD': ['MA', 'NY', 'PA', 'MD'],
#    'OH': ['MA', 'NY', 'PA', 'OH'],
#    'WV': ['MA', 'NY', 'PA', 'WV'],
#    'VA': ['MA', 'NY', 'PA', 'MD', 'VA'],
#    'IN': ['MA', 'NY', 'PA', 'OH', 'IN'],
#    'KY': ['MA', 'NY', 'PA', 'OH', 'KY'],
#    'MI': ['MA', 'NY', 'PA', 'OH', 'MI'],
#    'NC': ['MA', 'NY', 'PA', 'MD', 'VA', 'NC'],
#    'TN': ['MA', 'NY', 'PA', 'MD', 'VA', 'TN'],
#    'IL': ['MA', 'NY', 'PA', 'OH', 'IN', 'IL'],
#    'MO': ['MA', 'NY', 'PA', 'OH', 'KY', 'MO'],
#    'WI': ['MA', 'NY', 'PA', 'OH', 'MI', 'WI'],
#    'GA': ['MA', 'NY', 'PA', 'MD', 'VA', 'NC', 'GA'],
#    'SC': ['MA', 'NY', 'PA', 'MD', 'VA', 'NC', 'SC'],
#    'AL': ['MA', 'NY', 'PA', 'MD', 'VA', 'TN', 'AL'],
#    'AR': ['MA', 'NY', 'PA', 'MD', 'VA', 'TN', 'AR'],
#    'MS': ['MA', 'NY', 'PA', 'MD', 'VA', 'TN', 'MS'],
#    'IA': ['MA', 'NY', 'PA', 'OH', 'IN', 'IL', 'IA'],
#    'KS': ['MA', 'NY', 'PA', 'OH', 'KY', 'MO', 'KS'],
#    'NE': ['MA', 'NY', 'PA', 'OH', 'KY', 'MO', 'NE'],
#    'OK': ['MA', 'NY', 'PA', 'OH', 'KY', 'MO', 'OK'],
#    'MN': ['MA', 'NY', 'PA', 'OH', 'MI', 'WI', 'MN'],
#    'FL': ['MA', 'NY', 'PA', 'MD', 'VA', 'NC', 'GA', 'FL'],
#    'LA': ['MA', 'NY', 'PA', 'MD', 'VA', 'TN', 'AR', 'LA'],
#    'TX': ['MA', 'NY', 'PA', 'MD', 'VA', 'TN', 'AR', 'TX'],
#    'SD': ['MA', 'NY', 'PA', 'OH', 'IN', 'IL', 'IA', 'SD'],
#    'CO': ['MA', 'NY', 'PA', 'OH', 'KY', 'MO', 'KS', 'CO'],
#    'WY': ['MA', 'NY', 'PA', 'OH', 'KY', 'MO', 'NE', 'WY'],
#    'NM': ['MA', 'NY', 'PA', 'OH', 'KY', 'MO', 'OK', 'NM'],
#    'ND': ['MA', 'NY', 'PA', 'OH', 'MI', 'WI', 'MN', 'ND'],
#    'MT': ['MA', 'NY', 'PA', 'OH', 'IN', 'IL', 'IA', 'SD', 'MT'],
#    'UT': ['MA', 'NY', 'PA', 'OH', 'KY', 'MO', 'KS', 'CO', 'UT'],
#    'ID': ['MA', 'NY', 'PA', 'OH', 'KY', 'MO', 'NE', 'WY', 'ID'],
#    'AZ': ['MA', 'NY', 'PA', 'OH', 'KY', 'MO', 'OK', 'NM', 'AZ'],
#    'NV': ['MA', 'NY', 'PA', 'OH', 'KY', 'MO', 'KS', 'CO', 'UT', 'NV'],
#    'OR': ['MA', 'NY', 'PA', 'OH', 'KY', 'MO', 'NE', 'WY', 'ID', 'OR'],
#    'WA': ['MA', 'NY', 'PA', 'OH', 'KY', 'MO', 'NE', 'WY', 'ID', 'WA'],
#    'CA': ['MA', 'NY', 'PA', 'OH', 'KY', 'MO', 'OK', 'NM', 'AZ', 'CA']}),
#  ('MI',
#   {'MI': ['MI'],
#    'IN': ['MI', 'IN'],
#    'OH': ['MI', 'OH'],
#    'WI': ['MI', 'WI'],
#    'IL': ['MI', 'IN', 'IL'],
#    'KY': ['MI', 'IN', 'KY'],
#    'PA': ['MI', 'OH', 'PA'],
#    'WV': ['MI', 'OH', 'WV'],
#    'IA': ['MI', 'WI', 'IA'],
#    'MN': ['MI', 'WI', 'MN'],
#    'MO': ['MI', 'IN', 'IL', 'MO'],
#    'TN': ['MI', 'IN', 'KY', 'TN'],
#    'VA': ['MI', 'IN', 'KY', 'VA'],
#    'DE': ['MI', 'OH', 'PA', 'DE'],
#    'MD': ['MI', 'OH', 'PA', 'MD'],
#    'NJ': ['MI', 'OH', 'PA', 'NJ'],
#    'NY': ['MI', 'OH', 'PA', 'NY'],
#    'NE': ['MI', 'WI', 'IA', 'NE'],
#    'SD': ['MI', 'WI', 'IA', 'SD'],
#    'ND': ['MI', 'WI', 'MN', 'ND'],
#    'AR': ['MI', 'IN', 'IL', 'MO', 'AR'],
#    'KS': ['MI', 'IN', 'IL', 'MO', 'KS'],
#    'OK': ['MI', 'IN', 'IL', 'MO', 'OK'],
#    'AL': ['MI', 'IN', 'KY', 'TN', 'AL'],
#    'GA': ['MI', 'IN', 'KY', 'TN', 'GA'],
#    'MS': ['MI', 'IN', 'KY', 'TN', 'MS'],
#    'NC': ['MI', 'IN', 'KY', 'TN', 'NC'],
#    'CT': ['MI', 'OH', 'PA', 'NY', 'CT'],
#    'MA': ['MI', 'OH', 'PA', 'NY', 'MA'],
#    'VT': ['MI', 'OH', 'PA', 'NY', 'VT'],
#    'CO': ['MI', 'WI', 'IA', 'NE', 'CO'],
#    'WY': ['MI', 'WI', 'IA', 'NE', 'WY'],
#    'MT': ['MI', 'WI', 'IA', 'SD', 'MT'],
#    'LA': ['MI', 'IN', 'IL', 'MO', 'AR', 'LA'],
#    'TX': ['MI', 'IN', 'IL', 'MO', 'AR', 'TX'],
#    'NM': ['MI', 'IN', 'IL', 'MO', 'OK', 'NM'],
#    'FL': ['MI', 'IN', 'KY', 'TN', 'AL', 'FL'],
#    'SC': ['MI', 'IN', 'KY', 'TN', 'GA', 'SC'],
#    'UT': ['MI', 'WI', 'IA', 'NE', 'CO', 'UT'],
#    'ID': ['MI', 'WI', 'IA', 'NE', 'WY', 'ID'],
#    'AZ': ['MI', 'IN', 'IL', 'MO', 'OK', 'NM', 'AZ'],
#    'NV': ['MI', 'WI', 'IA', 'NE', 'CO', 'UT', 'NV'],
#    'OR': ['MI', 'WI', 'IA', 'NE', 'WY', 'ID', 'OR'],
#    'WA': ['MI', 'WI', 'IA', 'NE', 'WY', 'ID', 'WA'],
#    'CA': ['MI', 'IN', 'IL', 'MO', 'OK', 'NM', 'AZ', 'CA'],
#    'RI': ['MI', 'OH', 'PA', 'NY', 'CT', 'RI'],
#    'NH': ['MI', 'OH', 'PA', 'NY', 'MA', 'NH'],
#    'ME': ['MI', 'OH', 'PA', 'NY', 'MA', 'NH', 'ME']}),
#  ('MN',
#   {'MN': ['MN'],
#    'IA': ['MN', 'IA'],
#    'ND': ['MN', 'ND'],
#    'SD': ['MN', 'SD'],
#    'WI': ['MN', 'WI'],
#    'IL': ['MN', 'IA', 'IL'],
#    'MO': ['MN', 'IA', 'MO'],
#    'NE': ['MN', 'IA', 'NE'],
#    'MT': ['MN', 'ND', 'MT'],
#    'WY': ['MN', 'SD', 'WY'],
#    'MI': ['MN', 'WI', 'MI'],
#    'IN': ['MN', 'IA', 'IL', 'IN'],
#    'KY': ['MN', 'IA', 'IL', 'KY'],
#    'AR': ['MN', 'IA', 'MO', 'AR'],
#    'KS': ['MN', 'IA', 'MO', 'KS'],
#    'OK': ['MN', 'IA', 'MO', 'OK'],
#    'TN': ['MN', 'IA', 'MO', 'TN'],
#    'CO': ['MN', 'IA', 'NE', 'CO'],
#    'ID': ['MN', 'ND', 'MT', 'ID'],
#    'UT': ['MN', 'SD', 'WY', 'UT'],
#    'OH': ['MN', 'WI', 'MI', 'OH'],
#    'VA': ['MN', 'IA', 'IL', 'KY', 'VA'],
#    'WV': ['MN', 'IA', 'IL', 'KY', 'WV'],
#    'LA': ['MN', 'IA', 'MO', 'AR', 'LA'],
#    'MS': ['MN', 'IA', 'MO', 'AR', 'MS'],
#    'TX': ['MN', 'IA', 'MO', 'AR', 'TX'],
#    'NM': ['MN', 'IA', 'MO', 'OK', 'NM'],
#    'AL': ['MN', 'IA', 'MO', 'TN', 'AL'],
#    'GA': ['MN', 'IA', 'MO', 'TN', 'GA'],
#    'NC': ['MN', 'IA', 'MO', 'TN', 'NC'],
#    'NV': ['MN', 'ND', 'MT', 'ID', 'NV'],
#    'OR': ['MN', 'ND', 'MT', 'ID', 'OR'],
#    'WA': ['MN', 'ND', 'MT', 'ID', 'WA'],
#    'AZ': ['MN', 'SD', 'WY', 'UT', 'AZ'],
#    'PA': ['MN', 'WI', 'MI', 'OH', 'PA'],
#    'MD': ['MN', 'IA', 'IL', 'KY', 'VA', 'MD'],
#    'FL': ['MN', 'IA', 'MO', 'TN', 'AL', 'FL'],
#    'SC': ['MN', 'IA', 'MO', 'TN', 'GA', 'SC'],
#    'CA': ['MN', 'ND', 'MT', 'ID', 'NV', 'CA'],
#    'DE': ['MN', 'WI', 'MI', 'OH', 'PA', 'DE'],
#    'NJ': ['MN', 'WI', 'MI', 'OH', 'PA', 'NJ'],
#    'NY': ['MN', 'WI', 'MI', 'OH', 'PA', 'NY'],
#    'CT': ['MN', 'WI', 'MI', 'OH', 'PA', 'NY', 'CT'],
#    'MA': ['MN', 'WI', 'MI', 'OH', 'PA', 'NY', 'MA'],
#    'VT': ['MN', 'WI', 'MI', 'OH', 'PA', 'NY', 'VT'],
#    'RI': ['MN', 'WI', 'MI', 'OH', 'PA', 'NY', 'CT', 'RI'],
#    'NH': ['MN', 'WI', 'MI', 'OH', 'PA', 'NY', 'MA', 'NH'],
#    'ME': ['MN', 'WI', 'MI', 'OH', 'PA', 'NY', 'MA', 'NH', 'ME']}),
#  ('MS',
#   {'MS': ['MS'],
#    'AL': ['MS', 'AL'],
#    'AR': ['MS', 'AR'],
#    'LA': ['MS', 'LA'],
#    'TN': ['MS', 'TN'],
#    'FL': ['MS', 'AL', 'FL'],
#    'GA': ['MS', 'AL', 'GA'],
#    'MO': ['MS', 'AR', 'MO'],
#    'OK': ['MS', 'AR', 'OK'],
#    'TX': ['MS', 'AR', 'TX'],
#    'KY': ['MS', 'TN', 'KY'],
#    'NC': ['MS', 'TN', 'NC'],
#    'VA': ['MS', 'TN', 'VA'],
#    'SC': ['MS', 'AL', 'GA', 'SC'],
#    'IL': ['MS', 'AR', 'MO', 'IL'],
#    'IA': ['MS', 'AR', 'MO', 'IA'],
#    'KS': ['MS', 'AR', 'MO', 'KS'],
#    'NE': ['MS', 'AR', 'MO', 'NE'],
#    'CO': ['MS', 'AR', 'OK', 'CO'],
#    'NM': ['MS', 'AR', 'OK', 'NM'],
#    'IN': ['MS', 'TN', 'KY', 'IN'],
#    'OH': ['MS', 'TN', 'KY', 'OH'],
#    'WV': ['MS', 'TN', 'KY', 'WV'],
#    'MD': ['MS', 'TN', 'VA', 'MD'],
#    'WI': ['MS', 'AR', 'MO', 'IL', 'WI'],
#    'MN': ['MS', 'AR', 'MO', 'IA', 'MN'],
#    'SD': ['MS', 'AR', 'MO', 'IA', 'SD'],
#    'WY': ['MS', 'AR', 'MO', 'NE', 'WY'],
#    'UT': ['MS', 'AR', 'OK', 'CO', 'UT'],
#    'AZ': ['MS', 'AR', 'OK', 'NM', 'AZ'],
#    'MI': ['MS', 'TN', 'KY', 'IN', 'MI'],
#    'PA': ['MS', 'TN', 'KY', 'OH', 'PA'],
#    'DE': ['MS', 'TN', 'VA', 'MD', 'DE'],
#    'ND': ['MS', 'AR', 'MO', 'IA', 'MN', 'ND'],
#    'MT': ['MS', 'AR', 'MO', 'IA', 'SD', 'MT'],
#    'ID': ['MS', 'AR', 'MO', 'NE', 'WY', 'ID'],
#    'NV': ['MS', 'AR', 'OK', 'CO', 'UT', 'NV'],
#    'CA': ['MS', 'AR', 'OK', 'NM', 'AZ', 'CA'],
#    'NJ': ['MS', 'TN', 'KY', 'OH', 'PA', 'NJ'],
#    'NY': ['MS', 'TN', 'KY', 'OH', 'PA', 'NY'],
#    'OR': ['MS', 'AR', 'MO', 'NE', 'WY', 'ID', 'OR'],
#    'WA': ['MS', 'AR', 'MO', 'NE', 'WY', 'ID', 'WA'],
#    'CT': ['MS', 'TN', 'KY', 'OH', 'PA', 'NY', 'CT'],
#    'MA': ['MS', 'TN', 'KY', 'OH', 'PA', 'NY', 'MA'],
#    'VT': ['MS', 'TN', 'KY', 'OH', 'PA', 'NY', 'VT'],
#    'RI': ['MS', 'TN', 'KY', 'OH', 'PA', 'NY', 'CT', 'RI'],
#    'NH': ['MS', 'TN', 'KY', 'OH', 'PA', 'NY', 'MA', 'NH'],
#    'ME': ['MS', 'TN', 'KY', 'OH', 'PA', 'NY', 'MA', 'NH', 'ME']}),
#  ('MO',
#   {'MO': ['MO'],
#    'AR': ['MO', 'AR'],
#    'IL': ['MO', 'IL'],
#    'IA': ['MO', 'IA'],
#    'KS': ['MO', 'KS'],
#    'KY': ['MO', 'KY'],
#    'NE': ['MO', 'NE'],
#    'OK': ['MO', 'OK'],
#    'TN': ['MO', 'TN'],
#    'LA': ['MO', 'AR', 'LA'],
#    'MS': ['MO', 'AR', 'MS'],
#    'TX': ['MO', 'AR', 'TX'],
#    'IN': ['MO', 'IL', 'IN'],
#    'WI': ['MO', 'IL', 'WI'],
#    'MN': ['MO', 'IA', 'MN'],
#    'SD': ['MO', 'IA', 'SD'],
#    'CO': ['MO', 'KS', 'CO'],
#    'OH': ['MO', 'KY', 'OH'],
#    'VA': ['MO', 'KY', 'VA'],
#    'WV': ['MO', 'KY', 'WV'],
#    'WY': ['MO', 'NE', 'WY'],
#    'NM': ['MO', 'OK', 'NM'],
#    'AL': ['MO', 'TN', 'AL'],
#    'GA': ['MO', 'TN', 'GA'],
#    'NC': ['MO', 'TN', 'NC'],
#    'MI': ['MO', 'IL', 'IN', 'MI'],
#    'ND': ['MO', 'IA', 'MN', 'ND'],
#    'MT': ['MO', 'IA', 'SD', 'MT'],
#    'UT': ['MO', 'KS', 'CO', 'UT'],
#    'PA': ['MO', 'KY', 'OH', 'PA'],
#    'MD': ['MO', 'KY', 'VA', 'MD'],
#    'ID': ['MO', 'NE', 'WY', 'ID'],
#    'AZ': ['MO', 'OK', 'NM', 'AZ'],
#    'FL': ['MO', 'TN', 'AL', 'FL'],
#    'SC': ['MO', 'TN', 'GA', 'SC'],
#    'NV': ['MO', 'KS', 'CO', 'UT', 'NV'],
#    'DE': ['MO', 'KY', 'OH', 'PA', 'DE'],
#    'NJ': ['MO', 'KY', 'OH', 'PA', 'NJ'],
#    'NY': ['MO', 'KY', 'OH', 'PA', 'NY'],
#    'OR': ['MO', 'NE', 'WY', 'ID', 'OR'],
#    'WA': ['MO', 'NE', 'WY', 'ID', 'WA'],
#    'CA': ['MO', 'OK', 'NM', 'AZ', 'CA'],
#    'CT': ['MO', 'KY', 'OH', 'PA', 'NY', 'CT'],
#    'MA': ['MO', 'KY', 'OH', 'PA', 'NY', 'MA'],
#    'VT': ['MO', 'KY', 'OH', 'PA', 'NY', 'VT'],
#    'RI': ['MO', 'KY', 'OH', 'PA', 'NY', 'CT', 'RI'],
#    'NH': ['MO', 'KY', 'OH', 'PA', 'NY', 'MA', 'NH'],
#    'ME': ['MO', 'KY', 'OH', 'PA', 'NY', 'MA', 'NH', 'ME']}),
#  ('MT',
#   {'MT': ['MT'],
#    'ID': ['MT', 'ID'],
#    'ND': ['MT', 'ND'],
#    'SD': ['MT', 'SD'],
#    'WY': ['MT', 'WY'],
#    'NV': ['MT', 'ID', 'NV'],
#    'OR': ['MT', 'ID', 'OR'],
#    'UT': ['MT', 'ID', 'UT'],
#    'WA': ['MT', 'ID', 'WA'],
#    'MN': ['MT', 'ND', 'MN'],
#    'IA': ['MT', 'SD', 'IA'],
#    'NE': ['MT', 'SD', 'NE'],
#    'CO': ['MT', 'WY', 'CO'],
#    'AZ': ['MT', 'ID', 'NV', 'AZ'],
#    'CA': ['MT', 'ID', 'NV', 'CA'],
#    'WI': ['MT', 'ND', 'MN', 'WI'],
#    'IL': ['MT', 'SD', 'IA', 'IL'],
#    'MO': ['MT', 'SD', 'IA', 'MO'],
#    'KS': ['MT', 'SD', 'NE', 'KS'],
#    'NM': ['MT', 'WY', 'CO', 'NM'],
#    'OK': ['MT', 'WY', 'CO', 'OK'],
#    'MI': ['MT', 'ND', 'MN', 'WI', 'MI'],
#    'IN': ['MT', 'SD', 'IA', 'IL', 'IN'],
#    'KY': ['MT', 'SD', 'IA', 'IL', 'KY'],
#    'AR': ['MT', 'SD', 'IA', 'MO', 'AR'],
#    'TN': ['MT', 'SD', 'IA', 'MO', 'TN'],
#    'TX': ['MT', 'WY', 'CO', 'NM', 'TX'],
#    'OH': ['MT', 'ND', 'MN', 'WI', 'MI', 'OH'],
#    'VA': ['MT', 'SD', 'IA', 'IL', 'KY', 'VA'],
#    'WV': ['MT', 'SD', 'IA', 'IL', 'KY', 'WV'],
#    'LA': ['MT', 'SD', 'IA', 'MO', 'AR', 'LA'],
#    'MS': ['MT', 'SD', 'IA', 'MO', 'AR', 'MS'],
#    'AL': ['MT', 'SD', 'IA', 'MO', 'TN', 'AL'],
#    'GA': ['MT', 'SD', 'IA', 'MO', 'TN', 'GA'],
#    'NC': ['MT', 'SD', 'IA', 'MO', 'TN', 'NC'],
#    'PA': ['MT', 'ND', 'MN', 'WI', 'MI', 'OH', 'PA'],
#    'MD': ['MT', 'SD', 'IA', 'IL', 'KY', 'VA', 'MD'],
#    'FL': ['MT', 'SD', 'IA', 'MO', 'TN', 'AL', 'FL'],
#    'SC': ['MT', 'SD', 'IA', 'MO', 'TN', 'GA', 'SC'],
#    'DE': ['MT', 'ND', 'MN', 'WI', 'MI', 'OH', 'PA', 'DE'],
#    'NJ': ['MT', 'ND', 'MN', 'WI', 'MI', 'OH', 'PA', 'NJ'],
#    'NY': ['MT', 'ND', 'MN', 'WI', 'MI', 'OH', 'PA', 'NY'],
#    'CT': ['MT', 'ND', 'MN', 'WI', 'MI', 'OH', 'PA', 'NY', 'CT'],
#    'MA': ['MT', 'ND', 'MN', 'WI', 'MI', 'OH', 'PA', 'NY', 'MA'],
#    'VT': ['MT', 'ND', 'MN', 'WI', 'MI', 'OH', 'PA', 'NY', 'VT'],
#    'RI': ['MT', 'ND', 'MN', 'WI', 'MI', 'OH', 'PA', 'NY', 'CT', 'RI'],
#    'NH': ['MT', 'ND', 'MN', 'WI', 'MI', 'OH', 'PA', 'NY', 'MA', 'NH'],
#    'ME': ['MT', 'ND', 'MN', 'WI', 'MI', 'OH', 'PA', 'NY', 'MA', 'NH', 'ME']}),
#  ('NE',
#   {'NE': ['NE'],
# ...
#    'ME': ['TN', 'KY', 'OH', 'PA', 'NY', 'MA', 'NH', 'ME']}),
#  ('TX',
#   {'TX': ['TX'],
#    'AR': ['TX', 'AR'],
#    'LA': ['TX', 'LA'],
#    'NM': ['TX', 'NM'],
#    'OK': ['TX', 'OK'],
#    'MS': ['TX', 'AR', 'MS'],
#    'MO': ['TX', 'AR', 'MO'],
#    'TN': ['TX', 'AR', 'TN'],
#    'AZ': ['TX', 'NM', 'AZ'],
#    'CO': ['TX', 'NM', 'CO'],
#    'KS': ['TX', 'OK', 'KS'],
#    'AL': ['TX', 'AR', 'MS', 'AL'],
#    'IL': ['TX', 'AR', 'MO', 'IL'],
#    'IA': ['TX', 'AR', 'MO', 'IA'],
#    'KY': ['TX', 'AR', 'MO', 'KY'],
#    'NE': ['TX', 'AR', 'MO', 'NE'],
#    'GA': ['TX', 'AR', 'TN', 'GA'],
#    'NC': ['TX', 'AR', 'TN', 'NC'],
#    'VA': ['TX', 'AR', 'TN', 'VA'],
#    'CA': ['TX', 'NM', 'AZ', 'CA'],
#    'NV': ['TX', 'NM', 'AZ', 'NV'],
#    'UT': ['TX', 'NM', 'AZ', 'UT'],
#    'WY': ['TX', 'NM', 'CO', 'WY'],
#    'FL': ['TX', 'AR', 'MS', 'AL', 'FL'],
#    'IN': ['TX', 'AR', 'MO', 'IL', 'IN'],
#    'WI': ['TX', 'AR', 'MO', 'IL', 'WI'],
#    'MN': ['TX', 'AR', 'MO', 'IA', 'MN'],
#    'SD': ['TX', 'AR', 'MO', 'IA', 'SD'],
#    'OH': ['TX', 'AR', 'MO', 'KY', 'OH'],
#    'WV': ['TX', 'AR', 'MO', 'KY', 'WV'],
#    'SC': ['TX', 'AR', 'TN', 'GA', 'SC'],
#    'MD': ['TX', 'AR', 'TN', 'VA', 'MD'],
#    'OR': ['TX', 'NM', 'AZ', 'CA', 'OR'],
#    'ID': ['TX', 'NM', 'AZ', 'NV', 'ID'],
#    'MT': ['TX', 'NM', 'CO', 'WY', 'MT'],
#    'MI': ['TX', 'AR', 'MO', 'IL', 'IN', 'MI'],
#    'ND': ['TX', 'AR', 'MO', 'IA', 'MN', 'ND'],
#    'PA': ['TX', 'AR', 'MO', 'KY', 'OH', 'PA'],
#    'DE': ['TX', 'AR', 'TN', 'VA', 'MD', 'DE'],
#    'WA': ['TX', 'NM', 'AZ', 'CA', 'OR', 'WA'],
#    'NJ': ['TX', 'AR', 'MO', 'KY', 'OH', 'PA', 'NJ'],
#    'NY': ['TX', 'AR', 'MO', 'KY', 'OH', 'PA', 'NY'],
#    'CT': ['TX', 'AR', 'MO', 'KY', 'OH', 'PA', 'NY', 'CT'],
#    'MA': ['TX', 'AR', 'MO', 'KY', 'OH', 'PA', 'NY', 'MA'],
#    'VT': ['TX', 'AR', 'MO', 'KY', 'OH', 'PA', 'NY', 'VT'],
#    'RI': ['TX', 'AR', 'MO', 'KY', 'OH', 'PA', 'NY', 'CT', 'RI'],
#    'NH': ['TX', 'AR', 'MO', 'KY', 'OH', 'PA', 'NY', 'MA', 'NH'],
#    'ME': ['TX', 'AR', 'MO', 'KY', 'OH', 'PA', 'NY', 'MA', 'NH', 'ME']}),
#  ('UT',
#   {'UT': ['UT'],
#    'AZ': ['UT', 'AZ'],
#    'CO': ['UT', 'CO'],
#    'ID': ['UT', 'ID'],
#    'NV': ['UT', 'NV'],
#    'WY': ['UT', 'WY'],
#    'CA': ['UT', 'AZ', 'CA'],
#    'NM': ['UT', 'AZ', 'NM'],
#    'KS': ['UT', 'CO', 'KS'],
#    'NE': ['UT', 'CO', 'NE'],
#    'OK': ['UT', 'CO', 'OK'],
#    'MT': ['UT', 'ID', 'MT'],
#    'OR': ['UT', 'ID', 'OR'],
#    'WA': ['UT', 'ID', 'WA'],
#    'SD': ['UT', 'WY', 'SD'],
#    'TX': ['UT', 'AZ', 'NM', 'TX'],
#    'MO': ['UT', 'CO', 'KS', 'MO'],
#    'IA': ['UT', 'CO', 'NE', 'IA'],
#    'AR': ['UT', 'CO', 'OK', 'AR'],
#    'ND': ['UT', 'ID', 'MT', 'ND'],
#    'MN': ['UT', 'WY', 'SD', 'MN'],
#    'LA': ['UT', 'AZ', 'NM', 'TX', 'LA'],
#    'IL': ['UT', 'CO', 'KS', 'MO', 'IL'],
#    'KY': ['UT', 'CO', 'KS', 'MO', 'KY'],
#    'TN': ['UT', 'CO', 'KS', 'MO', 'TN'],
#    'WI': ['UT', 'CO', 'NE', 'IA', 'WI'],
#    'MS': ['UT', 'CO', 'OK', 'AR', 'MS'],
#    'IN': ['UT', 'CO', 'KS', 'MO', 'IL', 'IN'],
#    'OH': ['UT', 'CO', 'KS', 'MO', 'KY', 'OH'],
#    'VA': ['UT', 'CO', 'KS', 'MO', 'KY', 'VA'],
#    'WV': ['UT', 'CO', 'KS', 'MO', 'KY', 'WV'],
#    'AL': ['UT', 'CO', 'KS', 'MO', 'TN', 'AL'],
#    'GA': ['UT', 'CO', 'KS', 'MO', 'TN', 'GA'],
#    'NC': ['UT', 'CO', 'KS', 'MO', 'TN', 'NC'],
#    'MI': ['UT', 'CO', 'NE', 'IA', 'WI', 'MI'],
#    'PA': ['UT', 'CO', 'KS', 'MO', 'KY', 'OH', 'PA'],
#    'MD': ['UT', 'CO', 'KS', 'MO', 'KY', 'VA', 'MD'],
#    'FL': ['UT', 'CO', 'KS', 'MO', 'TN', 'AL', 'FL'],
#    'SC': ['UT', 'CO', 'KS', 'MO', 'TN', 'GA', 'SC'],
#    'DE': ['UT', 'CO', 'KS', 'MO', 'KY', 'OH', 'PA', 'DE'],
#    'NJ': ['UT', 'CO', 'KS', 'MO', 'KY', 'OH', 'PA', 'NJ'],
#    'NY': ['UT', 'CO', 'KS', 'MO', 'KY', 'OH', 'PA', 'NY'],
#    'CT': ['UT', 'CO', 'KS', 'MO', 'KY', 'OH', 'PA', 'NY', 'CT'],
#    'MA': ['UT', 'CO', 'KS', 'MO', 'KY', 'OH', 'PA', 'NY', 'MA'],
#    'VT': ['UT', 'CO', 'KS', 'MO', 'KY', 'OH', 'PA', 'NY', 'VT'],
#    'RI': ['UT', 'CO', 'KS', 'MO', 'KY', 'OH', 'PA', 'NY', 'CT', 'RI'],
#    'NH': ['UT', 'CO', 'KS', 'MO', 'KY', 'OH', 'PA', 'NY', 'MA', 'NH'],
#    'ME': ['UT', 'CO', 'KS', 'MO', 'KY', 'OH', 'PA', 'NY', 'MA', 'NH', 'ME']}),
#  ('VT',
#   {'VT': ['VT'],
#    'MA': ['VT', 'MA'],
#    'NH': ['VT', 'NH'],
#    'NY': ['VT', 'NY'],
#    'CT': ['VT', 'MA', 'CT'],
#    'RI': ['VT', 'MA', 'RI'],
#    'ME': ['VT', 'NH', 'ME'],
#    'NJ': ['VT', 'NY', 'PA', 'NJ'],
#    'PA': ['VT', 'NY', 'PA'],
#    'DE': ['VT', 'NY', 'PA', 'DE'],
#    'MD': ['VT', 'NY', 'PA', 'MD'],
#    'OH': ['VT', 'NY', 'PA', 'OH'],
#    'WV': ['VT', 'NY', 'PA', 'WV'],
#    'VA': ['VT', 'NY', 'PA', 'MD', 'VA'],
#    'IN': ['VT', 'NY', 'PA', 'OH', 'IN'],
#    'KY': ['VT', 'NY', 'PA', 'OH', 'KY'],
#    'MI': ['VT', 'NY', 'PA', 'OH', 'MI'],
#    'NC': ['VT', 'NY', 'PA', 'MD', 'VA', 'NC'],
#    'TN': ['VT', 'NY', 'PA', 'MD', 'VA', 'TN'],
#    'IL': ['VT', 'NY', 'PA', 'OH', 'IN', 'IL'],
#    'MO': ['VT', 'NY', 'PA', 'OH', 'KY', 'MO'],
#    'WI': ['VT', 'NY', 'PA', 'OH', 'MI', 'WI'],
#    'GA': ['VT', 'NY', 'PA', 'MD', 'VA', 'NC', 'GA'],
#    'SC': ['VT', 'NY', 'PA', 'MD', 'VA', 'NC', 'SC'],
#    'AL': ['VT', 'NY', 'PA', 'MD', 'VA', 'TN', 'AL'],
#    'AR': ['VT', 'NY', 'PA', 'MD', 'VA', 'TN', 'AR'],
#    'MS': ['VT', 'NY', 'PA', 'MD', 'VA', 'TN', 'MS'],
#    'IA': ['VT', 'NY', 'PA', 'OH', 'IN', 'IL', 'IA'],
#    'KS': ['VT', 'NY', 'PA', 'OH', 'KY', 'MO', 'KS'],
#    'NE': ['VT', 'NY', 'PA', 'OH', 'KY', 'MO', 'NE'],
#    'OK': ['VT', 'NY', 'PA', 'OH', 'KY', 'MO', 'OK'],
#    'MN': ['VT', 'NY', 'PA', 'OH', 'MI', 'WI', 'MN'],
#    'FL': ['VT', 'NY', 'PA', 'MD', 'VA', 'NC', 'GA', 'FL'],
#    'LA': ['VT', 'NY', 'PA', 'MD', 'VA', 'TN', 'AR', 'LA'],
#    'TX': ['VT', 'NY', 'PA', 'MD', 'VA', 'TN', 'AR', 'TX'],
#    'SD': ['VT', 'NY', 'PA', 'OH', 'IN', 'IL', 'IA', 'SD'],
#    'CO': ['VT', 'NY', 'PA', 'OH', 'KY', 'MO', 'KS', 'CO'],
#    'WY': ['VT', 'NY', 'PA', 'OH', 'KY', 'MO', 'NE', 'WY'],
#    'NM': ['VT', 'NY', 'PA', 'OH', 'KY', 'MO', 'OK', 'NM'],
#    'ND': ['VT', 'NY', 'PA', 'OH', 'MI', 'WI', 'MN', 'ND'],
#    'MT': ['VT', 'NY', 'PA', 'OH', 'IN', 'IL', 'IA', 'SD', 'MT'],
#    'UT': ['VT', 'NY', 'PA', 'OH', 'KY', 'MO', 'KS', 'CO', 'UT'],
#    'ID': ['VT', 'NY', 'PA', 'OH', 'KY', 'MO', 'NE', 'WY', 'ID'],
#    'AZ': ['VT', 'NY', 'PA', 'OH', 'KY', 'MO', 'OK', 'NM', 'AZ'],
#    'NV': ['VT', 'NY', 'PA', 'OH', 'KY', 'MO', 'KS', 'CO', 'UT', 'NV'],
#    'OR': ['VT', 'NY', 'PA', 'OH', 'KY', 'MO', 'NE', 'WY', 'ID', 'OR'],
#    'WA': ['VT', 'NY', 'PA', 'OH', 'KY', 'MO', 'NE', 'WY', 'ID', 'WA'],
#    'CA': ['VT', 'NY', 'PA', 'OH', 'KY', 'MO', 'OK', 'NM', 'AZ', 'CA']}),
#  ('VA',
#   {'VA': ['VA'],
#    'KY': ['VA', 'KY'],
#    'MD': ['VA', 'MD'],
#    'NC': ['VA', 'NC'],
#    'TN': ['VA', 'TN'],
#    'WV': ['VA', 'WV'],
#    'IL': ['VA', 'KY', 'IL'],
#    'IN': ['VA', 'KY', 'IN'],
#    'MO': ['VA', 'KY', 'MO'],
#    'OH': ['VA', 'KY', 'OH'],
#    'DE': ['VA', 'MD', 'DE'],
#    'PA': ['VA', 'MD', 'PA'],
#    'GA': ['VA', 'NC', 'GA'],
#    'SC': ['VA', 'NC', 'SC'],
#    'AL': ['VA', 'TN', 'AL'],
#    'AR': ['VA', 'TN', 'AR'],
#    'MS': ['VA', 'TN', 'MS'],
#    'IA': ['VA', 'KY', 'IL', 'IA'],
#    'WI': ['VA', 'KY', 'IL', 'WI'],
#    'MI': ['VA', 'KY', 'IN', 'MI'],
#    'KS': ['VA', 'KY', 'MO', 'KS'],
#    'NE': ['VA', 'KY', 'MO', 'NE'],
#    'OK': ['VA', 'KY', 'MO', 'OK'],
#    'NJ': ['VA', 'MD', 'PA', 'NJ'],
#    'NY': ['VA', 'MD', 'PA', 'NY'],
#    'FL': ['VA', 'NC', 'GA', 'FL'],
#    'LA': ['VA', 'TN', 'AR', 'LA'],
#    'TX': ['VA', 'TN', 'AR', 'TX'],
#    'MN': ['VA', 'KY', 'IL', 'IA', 'MN'],
#    'SD': ['VA', 'KY', 'IL', 'IA', 'SD'],
#    'CO': ['VA', 'KY', 'MO', 'KS', 'CO'],
#    'WY': ['VA', 'KY', 'MO', 'NE', 'WY'],
#    'NM': ['VA', 'KY', 'MO', 'OK', 'NM'],
#    'CT': ['VA', 'MD', 'PA', 'NY', 'CT'],
#    'MA': ['VA', 'MD', 'PA', 'NY', 'MA'],
#    'VT': ['VA', 'MD', 'PA', 'NY', 'VT'],
#    'ND': ['VA', 'KY', 'IL', 'IA', 'MN', 'ND'],
#    'MT': ['VA', 'KY', 'IL', 'IA', 'SD', 'MT'],
#    'UT': ['VA', 'KY', 'MO', 'KS', 'CO', 'UT'],
#    'ID': ['VA', 'KY', 'MO', 'NE', 'WY', 'ID'],
#    'AZ': ['VA', 'KY', 'MO', 'OK', 'NM', 'AZ'],
#    'NV': ['VA', 'KY', 'MO', 'KS', 'CO', 'UT', 'NV'],
#    'OR': ['VA', 'KY', 'MO', 'NE', 'WY', 'ID', 'OR'],
#    'WA': ['VA', 'KY', 'MO', 'NE', 'WY', 'ID', 'WA'],
#    'CA': ['VA', 'KY', 'MO', 'OK', 'NM', 'AZ', 'CA'],
#    'RI': ['VA', 'MD', 'PA', 'NY', 'CT', 'RI'],
#    'NH': ['VA', 'MD', 'PA', 'NY', 'MA', 'NH'],
#    'ME': ['VA', 'MD', 'PA', 'NY', 'MA', 'NH', 'ME']}),
#  ('WA',
#   {'WA': ['WA'],
#    'ID': ['WA', 'ID'],
#    'OR': ['WA', 'OR'],
#    'MT': ['WA', 'ID', 'MT'],
#    'NV': ['WA', 'ID', 'NV'],
#    'UT': ['WA', 'ID', 'UT'],
#    'WY': ['WA', 'ID', 'WY'],
#    'CA': ['WA', 'OR', 'CA'],
#    'ND': ['WA', 'ID', 'MT', 'ND'],
#    'SD': ['WA', 'ID', 'MT', 'SD'],
#    'AZ': ['WA', 'ID', 'NV', 'AZ'],
#    'CO': ['WA', 'ID', 'UT', 'CO'],
#    'NE': ['WA', 'ID', 'WY', 'NE'],
#    'MN': ['WA', 'ID', 'MT', 'ND', 'MN'],
#    'IA': ['WA', 'ID', 'MT', 'SD', 'IA'],
#    'NM': ['WA', 'ID', 'NV', 'AZ', 'NM'],
#    'KS': ['WA', 'ID', 'UT', 'CO', 'KS'],
#    'OK': ['WA', 'ID', 'UT', 'CO', 'OK'],
#    'MO': ['WA', 'ID', 'WY', 'NE', 'MO'],
#    'WI': ['WA', 'ID', 'MT', 'ND', 'MN', 'WI'],
#    'IL': ['WA', 'ID', 'MT', 'SD', 'IA', 'IL'],
#    'TX': ['WA', 'ID', 'NV', 'AZ', 'NM', 'TX'],
#    'AR': ['WA', 'ID', 'UT', 'CO', 'OK', 'AR'],
#    'KY': ['WA', 'ID', 'WY', 'NE', 'MO', 'KY'],
#    'TN': ['WA', 'ID', 'WY', 'NE', 'MO', 'TN'],
#    'MI': ['WA', 'ID', 'MT', 'ND', 'MN', 'WI', 'MI'],
#    'IN': ['WA', 'ID', 'MT', 'SD', 'IA', 'IL', 'IN'],
#    'LA': ['WA', 'ID', 'NV', 'AZ', 'NM', 'TX', 'LA'],
#    'MS': ['WA', 'ID', 'UT', 'CO', 'OK', 'AR', 'MS'],
#    'OH': ['WA', 'ID', 'WY', 'NE', 'MO', 'KY', 'OH'],
#    'VA': ['WA', 'ID', 'WY', 'NE', 'MO', 'KY', 'VA'],
#    'WV': ['WA', 'ID', 'WY', 'NE', 'MO', 'KY', 'WV'],
#    'AL': ['WA', 'ID', 'WY', 'NE', 'MO', 'TN', 'AL'],
#    'GA': ['WA', 'ID', 'WY', 'NE', 'MO', 'TN', 'GA'],
#    'NC': ['WA', 'ID', 'WY', 'NE', 'MO', 'TN', 'NC'],
#    'PA': ['WA', 'ID', 'WY', 'NE', 'MO', 'KY', 'OH', 'PA'],
#    'MD': ['WA', 'ID', 'WY', 'NE', 'MO', 'KY', 'VA', 'MD'],
#    'FL': ['WA', 'ID', 'WY', 'NE', 'MO', 'TN', 'AL', 'FL'],
#    'SC': ['WA', 'ID', 'WY', 'NE', 'MO', 'TN', 'GA', 'SC'],
#    'DE': ['WA', 'ID', 'WY', 'NE', 'MO', 'KY', 'OH', 'PA', 'DE'],
#    'NJ': ['WA', 'ID', 'WY', 'NE', 'MO', 'KY', 'OH', 'PA', 'NJ'],
#    'NY': ['WA', 'ID', 'WY', 'NE', 'MO', 'KY', 'OH', 'PA', 'NY'],
#    'CT': ['WA', 'ID', 'WY', 'NE', 'MO', 'KY', 'OH', 'PA', 'NY', 'CT'],
#    'MA': ['WA', 'ID', 'WY', 'NE', 'MO', 'KY', 'OH', 'PA', 'NY', 'MA'],
#    'VT': ['WA', 'ID', 'WY', 'NE', 'MO', 'KY', 'OH', 'PA', 'NY', 'VT'],
#    'RI': ['WA', 'ID', 'WY', 'NE', 'MO', 'KY', 'OH', 'PA', 'NY', 'CT', 'RI'],
#    'NH': ['WA', 'ID', 'WY', 'NE', 'MO', 'KY', 'OH', 'PA', 'NY', 'MA', 'NH'],
#    'ME': ['WA',
#     'ID',
#     'WY',
#     'NE',
#     'MO',
#     'KY',
#     'OH',
#     'PA',
#     'NY',
#     'MA',
#     'NH',
#     'ME']}),
#  ('WV',
#   {'WV': ['WV'],
#    'KY': ['WV', 'KY'],
#    'MD': ['WV', 'MD'],
#    'OH': ['WV', 'OH'],
#    'PA': ['WV', 'PA'],
#    'VA': ['WV', 'VA'],
#    'IL': ['WV', 'KY', 'IL'],
#    'IN': ['WV', 'KY', 'IN'],
#    'MO': ['WV', 'KY', 'MO'],
#    'TN': ['WV', 'KY', 'TN'],
#    'DE': ['WV', 'MD', 'DE'],
#    'MI': ['WV', 'OH', 'MI'],
#    'NJ': ['WV', 'PA', 'NJ'],
#    'NY': ['WV', 'PA', 'NY'],
#    'NC': ['WV', 'VA', 'NC'],
#    'IA': ['WV', 'KY', 'IL', 'IA'],
#    'WI': ['WV', 'KY', 'IL', 'WI'],
#    'AR': ['WV', 'KY', 'MO', 'AR'],
#    'KS': ['WV', 'KY', 'MO', 'KS'],
#    'NE': ['WV', 'KY', 'MO', 'NE'],
#    'OK': ['WV', 'KY', 'MO', 'OK'],
#    'AL': ['WV', 'KY', 'TN', 'AL'],
#    'GA': ['WV', 'KY', 'TN', 'GA'],
#    'MS': ['WV', 'KY', 'TN', 'MS'],
#    'CT': ['WV', 'PA', 'NY', 'CT'],
#    'MA': ['WV', 'PA', 'NY', 'MA'],
#    'VT': ['WV', 'PA', 'NY', 'VT'],
#    'SC': ['WV', 'VA', 'NC', 'SC'],
#    'MN': ['WV', 'KY', 'IL', 'IA', 'MN'],
#    'SD': ['WV', 'KY', 'IL', 'IA', 'SD'],
#    'LA': ['WV', 'KY', 'MO', 'AR', 'LA'],
#    'TX': ['WV', 'KY', 'MO', 'AR', 'TX'],
#    'CO': ['WV', 'KY', 'MO', 'KS', 'CO'],
#    'WY': ['WV', 'KY', 'MO', 'NE', 'WY'],
#    'NM': ['WV', 'KY', 'MO', 'OK', 'NM'],
#    'FL': ['WV', 'KY', 'TN', 'AL', 'FL'],
#    'ND': ['WV', 'KY', 'IL', 'IA', 'MN', 'ND'],
#    'MT': ['WV', 'KY', 'IL', 'IA', 'SD', 'MT'],
#    'UT': ['WV', 'KY', 'MO', 'KS', 'CO', 'UT'],
#    'ID': ['WV', 'KY', 'MO', 'NE', 'WY', 'ID'],
#    'AZ': ['WV', 'KY', 'MO', 'OK', 'NM', 'AZ'],
#    'NV': ['WV', 'KY', 'MO', 'KS', 'CO', 'UT', 'NV'],
#    'OR': ['WV', 'KY', 'MO', 'NE', 'WY', 'ID', 'OR'],
#    'WA': ['WV', 'KY', 'MO', 'NE', 'WY', 'ID', 'WA'],
#    'CA': ['WV', 'KY', 'MO', 'OK', 'NM', 'AZ', 'CA'],
#    'RI': ['WV', 'PA', 'NY', 'CT', 'RI'],
#    'NH': ['WV', 'PA', 'NY', 'MA', 'NH'],
#    'ME': ['WV', 'PA', 'NY', 'MA', 'NH', 'ME']}),
#  ('WI',
#   {'WI': ['WI'],
#    'IL': ['WI', 'IL'],
#    'IA': ['WI', 'IA'],
#    'MI': ['WI', 'MI'],
#    'MN': ['WI', 'MN'],
#    'IN': ['WI', 'IL', 'IN'],
#    'KY': ['WI', 'IL', 'KY'],
#    'MO': ['WI', 'IL', 'MO'],
#    'NE': ['WI', 'IA', 'NE'],
#    'SD': ['WI', 'IA', 'SD'],
#    'OH': ['WI', 'MI', 'OH'],
#    'ND': ['WI', 'MN', 'ND'],
#    'TN': ['WI', 'IL', 'KY', 'TN'],
#    'VA': ['WI', 'IL', 'KY', 'VA'],
#    'WV': ['WI', 'IL', 'KY', 'WV'],
#    'AR': ['WI', 'IL', 'MO', 'AR'],
#    'KS': ['WI', 'IL', 'MO', 'KS'],
#    'OK': ['WI', 'IL', 'MO', 'OK'],
#    'CO': ['WI', 'IA', 'NE', 'CO'],
#    'WY': ['WI', 'IA', 'NE', 'WY'],
#    'MT': ['WI', 'IA', 'SD', 'MT'],
#    'PA': ['WI', 'MI', 'OH', 'PA'],
#    'AL': ['WI', 'IL', 'KY', 'TN', 'AL'],
#    'GA': ['WI', 'IL', 'KY', 'TN', 'GA'],
#    'MS': ['WI', 'IL', 'KY', 'TN', 'MS'],
#    'NC': ['WI', 'IL', 'KY', 'TN', 'NC'],
#    'MD': ['WI', 'IL', 'KY', 'VA', 'MD'],
#    'LA': ['WI', 'IL', 'MO', 'AR', 'LA'],
#    'TX': ['WI', 'IL', 'MO', 'AR', 'TX'],
#    'NM': ['WI', 'IL', 'MO', 'OK', 'NM'],
#    'UT': ['WI', 'IA', 'NE', 'CO', 'UT'],
#    'ID': ['WI', 'IA', 'NE', 'WY', 'ID'],
#    'DE': ['WI', 'MI', 'OH', 'PA', 'DE'],
#    'NJ': ['WI', 'MI', 'OH', 'PA', 'NJ'],
#    'NY': ['WI', 'MI', 'OH', 'PA', 'NY'],
#    'FL': ['WI', 'IL', 'KY', 'TN', 'AL', 'FL'],
#    'SC': ['WI', 'IL', 'KY', 'TN', 'GA', 'SC'],
#    'AZ': ['WI', 'IL', 'MO', 'OK', 'NM', 'AZ'],
#    'NV': ['WI', 'IA', 'NE', 'CO', 'UT', 'NV'],
#    'OR': ['WI', 'IA', 'NE', 'WY', 'ID', 'OR'],
#    'WA': ['WI', 'IA', 'NE', 'WY', 'ID', 'WA'],
#    'CT': ['WI', 'MI', 'OH', 'PA', 'NY', 'CT'],
#    'MA': ['WI', 'MI', 'OH', 'PA', 'NY', 'MA'],
#    'VT': ['WI', 'MI', 'OH', 'PA', 'NY', 'VT'],
#    'CA': ['WI', 'IL', 'MO', 'OK', 'NM', 'AZ', 'CA'],
#    'RI': ['WI', 'MI', 'OH', 'PA', 'NY', 'CT', 'RI'],
#    'NH': ['WI', 'MI', 'OH', 'PA', 'NY', 'MA', 'NH'],
#    'ME': ['WI', 'MI', 'OH', 'PA', 'NY', 'MA', 'NH', 'ME']}),
#  ('WY',
#   {'WY': ['WY'],
#    'CO': ['WY', 'CO'],
#    'ID': ['WY', 'ID'],
#    'MT': ['WY', 'MT'],
#    'NE': ['WY', 'NE'],
#    'SD': ['WY', 'SD'],
#    'UT': ['WY', 'UT'],
#    'KS': ['WY', 'CO', 'KS'],
#    'NM': ['WY', 'CO', 'NM'],
#    'OK': ['WY', 'CO', 'OK'],
#    'NV': ['WY', 'ID', 'NV'],
#    'OR': ['WY', 'ID', 'OR'],
#    'WA': ['WY', 'ID', 'WA'],
#    'ND': ['WY', 'MT', 'ND'],
#    'IA': ['WY', 'NE', 'IA'],
#    'MO': ['WY', 'NE', 'MO'],
#    'MN': ['WY', 'SD', 'MN'],
#    'AZ': ['WY', 'UT', 'AZ'],
#    'TX': ['WY', 'CO', 'NM', 'TX'],
#    'AR': ['WY', 'CO', 'OK', 'AR'],
#    'CA': ['WY', 'ID', 'NV', 'CA'],
#    'IL': ['WY', 'NE', 'IA', 'IL'],
#    'WI': ['WY', 'NE', 'IA', 'WI'],
#    'KY': ['WY', 'NE', 'MO', 'KY'],
#    'TN': ['WY', 'NE', 'MO', 'TN'],
#    'LA': ['WY', 'CO', 'NM', 'TX', 'LA'],
#    'MS': ['WY', 'CO', 'OK', 'AR', 'MS'],
#    'IN': ['WY', 'NE', 'IA', 'IL', 'IN'],
#    'MI': ['WY', 'NE', 'IA', 'WI', 'MI'],
#    'OH': ['WY', 'NE', 'MO', 'KY', 'OH'],
#    'VA': ['WY', 'NE', 'MO', 'KY', 'VA'],
#    'WV': ['WY', 'NE', 'MO', 'KY', 'WV'],
#    'AL': ['WY', 'NE', 'MO', 'TN', 'AL'],
#    'GA': ['WY', 'NE', 'MO', 'TN', 'GA'],
#    'NC': ['WY', 'NE', 'MO', 'TN', 'NC'],
#    'PA': ['WY', 'NE', 'MO', 'KY', 'OH', 'PA'],
#    'MD': ['WY', 'NE', 'MO', 'KY', 'VA', 'MD'],
#    'FL': ['WY', 'NE', 'MO', 'TN', 'AL', 'FL'],
#    'SC': ['WY', 'NE', 'MO', 'TN', 'GA', 'SC'],
#    'DE': ['WY', 'NE', 'MO', 'KY', 'OH', 'PA', 'DE'],
#    'NJ': ['WY', 'NE', 'MO', 'KY', 'OH', 'PA', 'NJ'],
#    'NY': ['WY', 'NE', 'MO', 'KY', 'OH', 'PA', 'NY'],
#    'CT': ['WY', 'NE', 'MO', 'KY', 'OH', 'PA', 'NY', 'CT'],
#    'MA': ['WY', 'NE', 'MO', 'KY', 'OH', 'PA', 'NY', 'MA'],
#    'VT': ['WY', 'NE', 'MO', 'KY', 'OH', 'PA', 'NY', 'VT'],
#    'RI': ['WY', 'NE', 'MO', 'KY', 'OH', 'PA', 'NY', 'CT', 'RI'],
#    'NH': ['WY', 'NE', 'MO', 'KY', 'OH', 'PA', 'NY', 'MA', 'NH'],
#    'ME': ['WY', 'NE', 'MO', 'KY', 'OH', 'PA', 'NY', 'MA', 'NH', 'ME']})]

# %%
nx.average_clustering(borders48)
# Out:
# 0.48968253968253966

# %%
nx.degree_histogram(borders)
# Out:
# [2, 1, 4, 9, 13, 9, 9, 1, 2]

# %%
nx.average_degree_connectivity(borders48)
# Out:
# {4: 4.903846153846154,
#  6: 5.148148148148148,
#  3: 4.2592592592592595,
#  2: 4.5,
#  5: 4.7555555555555555,
#  7: 5.714285714285714,
#  1: 3.0,
#  8: 5.6875}

# %%
nx.average_neighbor_degree(borders48)
# Out:
# {'AL': 4.75,
#  'AZ': 4.25,
#  'AR': 5.5,
#  'CA': 4.333333333333333,
#  'CO': 5.166666666666667,
#  'CT': 4.0,
#  'DE': 4.333333333333333,
#  'FL': 4.5,
#  'GA': 4.0,
#  'ID': 4.333333333333333,
#  'IL': 5.8,
#  'IN': 5.0,
#  'IA': 5.5,
#  'KS': 6.5,
#  'KY': 5.714285714285714,
#  'LA': 4.666666666666667,
#  'ME': 3.0,
#  'MD': 4.75,
#  'MA': 3.2,
#  'MI': 4.333333333333333,
#  'MN': 4.75,
#  'MS': 5.25,
#  'MO': 6.0,
#  'MT': 5.25,
#  'NE': 6.0,
#  'NV': 4.4,
#  'NH': 3.0,
#  'NJ': 4.666666666666667,
#  'NM': 5.0,
#  'NY': 4.0,
#  'NC': 5.0,
#  'ND': 4.666666666666667,
#  'OH': 5.0,
#  'OK': 5.333333333333333,
#  'OR': 4.0,
#  'PA': 4.166666666666667,
#  'RI': 4.0,
#  'SC': 4.5,
#  'SD': 4.833333333333333,
#  'TN': 5.375,
#  'TX': 4.75,
#  'UT': 5.4,
#  'VT': 4.333333333333333,
#  'VA': 5.6,
#  'WA': 5.0,
#  'WV': 5.4,
#  'WI': 4.5,
#  'WY': 5.5}

# %%
nx.average_shortest_path_length(borders48)
# Out:
# 4.168439716312057

# %%
nx.node_clique_number(borders)
# Out:
# {'AL': 3,
#  'AK': 1,
#  'AZ': 3,
#  'AR': 3,
#  'CA': 3,
#  'CO': 3,
#  'CT': 3,
#  'DE': 3,
#  'FL': 3,
#  'GA': 3,
#  'HI': 1,
#  'ID': 3,
#  'IL': 3,
#  'IN': 3,
#  'IA': 3,
#  'KS': 3,
#  'KY': 3,
#  'LA': 3,
#  'ME': 2,
#  'MD': 3,
#  'MA': 3,
#  'MI': 3,
#  'MN': 3,
#  'MS': 3,
#  'MO': 3,
#  'MT': 3,
#  'NE': 3,
#  'NV': 3,
#  'NH': 3,
#  'NJ': 3,
#  'NM': 3,
#  'NY': 3,
#  'NC': 3,
#  'ND': 3,
#  'OH': 3,
#  'OK': 3,
#  'OR': 3,
#  'PA': 3,
#  'RI': 3,
#  'SC': 3,
#  'SD': 3,
#  'TN': 3,
#  'TX': 3,
#  'UT': 3,
#  'VT': 3,
#  'VA': 3,
#  'WA': 3,
#  'WV': 3,
#  'WI': 3,
#  'WY': 3}

# %%
nx.betweenness_centrality(borders48)
# Out:
# {'AL': 0.02179451240505819,
#  'AZ': 0.04833143468364481,
#  'AR': 0.07883618719650172,
#  'CA': 0.003103888094637401,
#  'CO': 0.06580445579259077,
#  'CT': 0.01942645698427382,
#  'DE': 0.0027765070780796956,
#  'FL': 0.0,
#  'GA': 0.03571176485145033,
#  'ID': 0.0885033686455478,
#  'IL': 0.04390375549563193,
#  'IN': 0.014227617569874309,
#  'IA': 0.08191052764793336,
#  'KS': 0.015790054585151717,
#  'KY': 0.28540785133974644,
#  'LA': 0.003210788594692388,
#  'ME': 0.0,
#  'MD': 0.05059772241179293,
#  'MA': 0.0633672525439408,
#  'MI': 0.03965160409149942,
#  'MN': 0.02946605951212371,
#  'MS': 0.015738901862861157,
#  'MO': 0.35891442260482853,
#  'MT': 0.01844288139787476,
#  'NE': 0.1605104596296623,
#  'NV': 0.011894640617039364,
#  'NH': 0.0425531914893617,
#  'NJ': 0.0032377428307123037,
#  'NM': 0.07542009711498511,
#  'NY': 0.22802960222016652,
#  'NC': 0.03386507880032394,
#  'ND': 0.004578191051062387,
#  'OH': 0.1626540185201946,
#  'OK': 0.1120098979347662,
#  'OR': 0.005617267809078935,
#  'PA': 0.296461795434578,
#  'RI': 0.0,
#  'SC': 0.0,
#  'SD': 0.05906082850491148,
#  'TN': 0.22007277005437514,
#  'TX': 0.022236602948906375,
#  'UT': 0.03841393370915151,
#  'VT': 0.03885291396854764,
#  'VA': 0.09709239866268025,
#  'WA': 0.0,
#  'WV': 0.13474086562132587,
#  'WI': 0.04727083575437259,
#  'WY': 0.12670681678142565}

# %%
# Exercise 1:

# Which state has the highest betweenness centrality?

# HINT: Use the tools inside networkx!
for state, num in nx.betweenness_centrality(borders48).items():
    if num == max(nx.betweenness_centrality(borders48).values()):
        print(state)
# Out:
# MO

# %%
# Exercise 2:

# Which state has the highest degree centrality?
for state, num in nx.degree_centrality(borders48).items():
    if num == max(nx.degree_centrality(borders48).values()):
        print(state)
# Out:
# MO
# TN

# %%
# Exercise 3:

# Which state has the highest closeness centrality?
for state, num in nx.closeness_centrality(borders48).items():
    if num == max(nx.closeness_centrality(borders48).values()):
        print(state)
# Out:
# MO

# %%
# Exercise 4:

# Which border has the highest betweenness centrality?

# And what is the interpretation of this?
for state, num in nx.edge_betweenness_centrality(borders48).items():
    if num == max(nx.edge_betweenness_centrality(borders48).values()):
        print(state)
# Out:
# ('NY', 'PA')
